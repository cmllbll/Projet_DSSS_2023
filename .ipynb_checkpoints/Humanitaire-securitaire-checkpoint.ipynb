# %%
import spacy
import pandas as pd
import random
# Out:
# C:\Users\tlp\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ### Data

# %%
df = pd.read_csv(r'data_cleaned/initial_corpus.csv')

print(df.shape)
df.head()
# Out:
# (8918, 8)
#                     Journal  \
# 0   Le Figaro, no. 23520
# 1               Le Monde
# 2   Le Figaro (site web)
# 3    Le Monde (site web)
# 4    Le Monde (site web)
#
#                                                Titre        Date  \
# 0                 L'agenda caché de Moscou en Italie  2020-03-30
# 1  Récit   Les trois semaines qui ont chamboulé l...  2020-03-27
# 2  Élargissement de l’Union européenne à l’heure ...  2020-03-26
# 3  Coronavirus : les trois semaines qui ont chamb...  2020-03-26
# 4  Marc Lazar : « Plus l’Italie fait nation face ...  2020-03-25
#
#                                               Auteur  \
# 0                                 Lasserre, Isabelle
# 1  Éric Albert, Cécile Boutelet, Jérôme Gautheret...
# 2                                  Tandonnet, Maxime
# 3  Eric Albert, Jérôme Gautheret, Cécile Boutelet...
# 4                                         Marc Lazar
#
#                                                Texte  \
# 0  LES SYMBOLES comptent parfois plus que les fai...
# 1  Londres, Berlin, Rome et Bruxelles corresponda...
# 2  Fin observateur de la vie politique française ...
# 3  Jeudi 26 mars, les Vingt-Sept doivent se réuni...
# 4  Tribune. L’Italie est le pays qui enregistre à...
#
#                                        extrait_debut  \
# 0   Sur les camions militaires qui, en colonnes, ...
# 1   - Jeudi 26 mars, les Vingt-Sept devaient se r...
# 2  contributeur régulier du FigaroVox, Maxime Tan...
# 3  n visioconférence pour la troisième fois en mo...
# 4   date du 25 mars le plus grand nombre de morts...
#
#                                          extrait_fin CJournal
# 0  Deux semaines pour se ressaisir et s'unir ou p...   Figaro
# 1  pandémie touche tout le monde, indifféremment ...    Monde
# 2  es yeux et de se préparer au changement d’un m...   Figaro
# 3  e la tenue de ses comptes publics, n’est pas s...    Monde
# 4  t de la School of Government de la Luiss (Libr...    Monde

# %% [markdown]
# ### Liste des pays

# %%
import pandas as pd

# Liste des pays avec leur nationalité, capitale et continent
pays_nationalite = [
    ("Afghanistan", "Afghan", "Kaboul", "Asie"),
    ("Afrique du Sud", "Sud-africain", "Pretoria", "Afrique"),
    ("Albanie", "Albanais", "Tirana", "Europe"),
    ("Algérie", "Algérien", "Alger", "Afrique"),
    ("Allemagne", "Allemand", "Berlin", "Europe"),
    ("Andorre", "Andorran", "Andorre-la-Vieille", "Europe"),
    ("Angola", "Angolais", "Luanda", "Afrique"),
    ("Antigua-et-Barbuda", "Antiguais", "Saint John's", "Amérique du Nord"),
    ("Arabie saoudite", "Saoudien", "Riyad", "Asie"),
    ("Argentine", "Argentin", "Buenos Aires", "Amérique du Sud"),
    ("Arménie", "Arménien", "Erevan", "Europe"),
    ("Australie", "Australien", "Canberra", "Océanie"),
    ("Autriche", "Autrichien", "Vienne", "Europe"),
    ("Azerbaïdjan", "Azéri", "Bakou", "Europe"),
    # Continuer la liste avec les autres pays et leurs informations
    ("Zimbabwe", "Zimbabwéen", "Harare", "Afrique"),
    ("Égypte", "Égyptien", "Le Caire", "Afrique"),
    ("Émirats arabes unis", "Émirien", "Abou Dabi", "Asie"),
    ("Équateur", "Équatorien", "Quito", "Amérique du Sud"),
    ("Érythrée", "Érythréen", "Asmara", "Afrique"),
    ("Espagne", "Espagnol", "Madrid", "Europe"),
    ("Estonie", "Estonien", "Tallinn", "Europe"),
    ("États-Unis", "Américain", "Washington", "Amérique du Nord"),
    ("Éthiopie", "Éthiopien", "Addis-Abeba", "Afrique"),
    ("Fidji", "Fidjien", "Suva", "Océanie"),
    ("Finlande", "Finlandais", "Helsinki", "Europe"),
    ("France", "Français", "Paris", "Europe"),
    ("Gabon", "Gabonais", "Libreville", "Afrique"),
    ("Gambie", "Gambien", "Banjul", "Afrique"),
    ("Géorgie", "Géorgien", "Tbilissi", "Europe"),
    ("Ghana", "Ghanéen", "Accra", "Afrique"),
    ("Grèce", "Grec", "Athènes", "Europe"),
    ("Grenade", "Grenadien", "Saint-Georges", "Amérique du Nord"),
    ("Guatemala", "Guatémaltèque", "Guatemala", "Amérique du Nord"),
    ("Guinée", "Guinéen", "Conakry", "Afrique"),
    ("Guinée-Bissau", "Bissau-Guinéen", "Bissau", "Afrique"),
    ("Guinée équatoriale", "Équatoguinéen", "Malabo", "Afrique"),
    ("Guyana", "Guyanais", "Georgetown", "Amérique du Sud"),
    ("Haïti", "Haïtien", "Port-au-Prince", "Amérique du Nord"),
    ("Honduras", "Hondurien", "Tegucigalpa", "Amérique du Nord"),
    ("Hongrie", "Hongrois", "Budapest", "Europe"),
    ("Îles Marshall", "Marshallais", "Majuro", "Océanie"),
    ("Inde", "Indien", "New Delhi", "Asie"),
    ("Indonésie", "Indonésien", "Jakarta", "Asie"),
    ("Irak", "Irakien", "Bagdad", "Asie"),
    ("Iran", "Iranien", "Téhéran", "Asie"),
    ("Irlande", "Irlandais", "Dublin", "Europe"),
    ("Islande", "Islandais", "Reykjavik", "Europe"),
    ("Israël", "Israélien", "Jérusalem", "Asie"),
    ("Italie", "Italien", "Rome", "Europe"),
    ("Jamaïque", "Jamaïcain", "Kingston", "Amérique du Nord"),
    ("Japon", "Japonais", "Tokyo", "Asie"),
    ("Jordanie", "Jordanien", "Amman", "Asie"),
    ("Kazakhstan", "Kazakh", "Noursoultan", "Asie"),
    ("Kenya", "Kényan", "Nairobi", "Afrique"),
    ("Kirghizistan", "Kirghize", "Bichkek", "Asie"),
    ("Kiribati", "Kiribatien", "Tarawa", "Océanie"),
    ("Koweït", "Koweïtien", "Koweït", "Asie"),
    ("Laos", "Laotien", "Vientiane", "Asie"),
    ("Lesotho", "Lesothan", "Maseru", "Afrique"),
    ("Lettonie", "Letton", "Riga", "Europe"),
    ("Liban", "Libanais", "Beyrouth", "Asie"),
    ("Libéria", "Libérien", "Monrovia", "Afrique"),
    ("Libye", "Libyen", "Tripoli", "Afrique"),
    ("Liechtenstein", "Liechtensteinois", "Vaduz", "Europe"),
    ("Lituanie", "Lituanien", "Vilnius", "Europe"),
    ("Luxembourg", "Luxembourgeois", "Luxembourg", "Europe"),
    ("Macédoine du Nord", "Macédonien", "Skopje", "Europe"),
    ("Madagascar", "Malgache", "Antananarivo", "Afrique"),
    ("Malaisie", "Malaisien", "Kuala Lumpur", "Asie"),
    ("Malawi", "Malawien", "Lilongwe", "Afrique"),
    ("Maldives", "Maldivien", "Malé", "Asie"),
    ("Mali", "Malien", "Bamako", "Afrique"),
    ("Malte", "Maltais", "La Valette", "Europe"),
    ("Maroc", "Marocain", "Rabat", "Afrique"),
    ("Maurice", "Mauricien", "Port-Louis", "Afrique"),
    ("Mauritanie", "Mauritanien", "Nouakchott", "Afrique"),
    ("Mexique", "Mexicain", "Mexico", "Amérique du Nord"),
    ("Micronésie", "Micronésien", "Palikir", "Océanie"),
    ("Moldavie", "Moldave", "Chisinau", "Europe"),
    ("Monaco", "Monégasque", "Monaco", "Europe"),
    ("Mongolie", "Mongol", "Oulan-Bator", "Asie"),
    ("Monténégro", "Monténégrin", "Podgorica", "Europe"),
    ("Mozambique", "Mozambicain", "Maputo", "Afrique"),
    ("Namibie", "Namibien", "Windhoek", "Afrique"),
    ("Nauru", "Nauruan", "Yaren", "Océanie"),
    ("Népal", "Népalais", "Katmandou", "Asie"),
    ("Nicaragua", "Nicaraguayen", "Managua", "Amérique du Nord"),
    ("Niger", "Nigérien", "Niamey", "Afrique"),
    ("Nigeria", "Nigérian", "Abuja", "Afrique"),
    ("Niue", "Niuéen", "Alofi", "Océanie"),
    ("Norvège", "Norvégien", "Oslo", "Europe"),
    ("Nouvelle-Zélande", "Néo-zélandais", "Wellington", "Océanie"),
    ("Oman", "Omanais", "Mascate", "Asie"),
    ("Ouganda", "Ougandais", "Kampala", "Afrique"),
    ("Ouzbékistan", "Ouzbek", "Tachkent", "Asie"),
    ("Pakistan", "Pakistanais", "Islamabad", "Asie"),
    ("Palaos", "Palauan", "Ngerulmud", "Océanie"),
    ("Panama", "Panaméen", "Panama", "Amérique du Nord"),
    ("Papouasie-Nouvelle-Guinée", "Papouan-Néo-Guinéen", "Port Moresby", "Océanie"),
    ("Paraguay", "Paraguayen", "Asunción", "Amérique du Sud"),
    ("Pays-Bas", "Néerlandais", "Amsterdam", "Europe"),
    ("Pérou", "Péruvien", "Lima", "Amérique du Sud"),
    ("Philippines", "Philippin", "Manille", "Asie"),
    ("Pologne", "Polonais", "Varsovie", "Europe"),
    ("Portugal", "Portugais", "Lisbonne", "Europe"),
    ("Qatar", "Qatarien", "Doha", "Asie"),
    ("République centrafricaine", "Centrafricain", "Bangui", "Afrique"),
    ("République démocratique du Congo", "Congolais", "Kinshasa", "Afrique"),
    ("République dominicaine", "Dominicain", "Saint-Domingue", "Amérique du Nord"),
    ("République tchèque", "Tchèque", "Prague", "Europe"),
    ("Roumanie", "Roumain", "Bucarest", "Europe"),
    ("Royaume-Uni", "Britannique", "Londres", "Europe"),
    ("Russie", "Russe", "Moscou", "Europe"),
    ("Rwanda", "Rwandais", "Kigali", "Afrique"),
    ("Saint-Christophe-et-Niévès", "Saint-Christophien et Névicien", "Basseterre", "Amérique du Nord"),
    ("Saint-Marin", "Saint-Marinais", "Saint-Marin", "Europe"),
    ("Saint-Vincent-et-les-Grenadines", "Saint-Vincentais et Grenadin", "Kingstown", "Amérique du Nord"),
    ("Sainte-Lucie", "Saint-Lucien", "Castries", "Amérique du Nord"),
    ("Salomon", "Salomonais", "Honiara", "Océanie"),
    ("Salvador", "Salvadorien", "San Salvador", "Amérique du Nord"),
    ("Samoa", "Samoan", "Apia", "Océanie"),
    ("São Tomé-et-Príncipe", "Santoméen", "São Tomé", "Afrique"),
    ("Sénégal", "Sénégalais", "Dakar", "Afrique"),
    ("Serbie", "Serbe", "Belgrade", "Europe"),
    ("Seychelles", "Seychellois", "Victoria", "Afrique"),
    ("Sierra Leone", "Sierra-léonais", "Freetown", "Afrique"),
    ("Singapour", "Singapourien", "Singapour", "Asie"),
    ("Slovaquie", "Slovaque", "Bratislava", "Europe"),
    ("Slovénie", "Slovène", "Ljubljana", "Europe"),
    ("Somalie", "Somalien", "Mogadiscio", "Afrique"),
    ("Soudan", "Soudanais", "Khartoum", "Afrique"),
    ("Soudan du Sud", "Sud-Soudanais", "Djouba", "Afrique"),
    ("Sri Lanka", "Sri-lankais", "Sri Jayawardenapura Kotte", "Asie"),
    ("Suède", "Suédois", "Stockholm", "Europe"),
    ("Suisse", "Suisse", "Berne", "Europe"),
    ("Suriname", "Surinamien", "Paramaribo", "Amérique du Sud"),
    ("Syrie", "Syrien", "Damas", "Asie"),
    ("Swaziland", "Swazilandais", "Mbabane", "Afrique"),
    ("Tadjikistan", "Tadjik", "Douchanbé", "Asie"),
    ("Tanzanie", "Tanzanien", "Dodoma", "Afrique"),
    ("Tchad", "Tchadien", "N'Djaména", "Afrique"),
    ("Thaïlande", "Thaïlandais", "Bangkok", "Asie"),
    ("Timor oriental", "Est-timorais", "Dili", "Asie"),
    ("Togo", "Togolais", "Lomé", "Afrique"),
    ("Tonga", "Tongan", "Nuku'alofa", "Océanie"),
    ("Trinité-et-Tobago", "Trinidadien", "Port-d'Espagne", "Amérique du Nord"),
    ("Tunisie", "Tunisien", "Tunis", "Afrique"),
    ("Turkménistan", "Turkmène", "Achgabat", "Asie"),
    ("Turquie", "Turc", "Ankara", "Europe"),
    ("Tuvalu", "Tuvaluan", "Funafuti", "Océanie"),
    ("Ukraine", "Ukrainien", "Kiev", "Europe"),
    ("Uruguay", "Uruguayen", "Montevideo", "Amérique du Sud"),
    ("Vanuatu", "Vanuatuan", "Port-Vila", "Océanie"),
    ("Vatican", "Vaticanais", "Vatican", "Europe"),
    ("Venezuela", "Vénézuélien", "Caracas", "Amérique du Sud"),
    ("Viêt Nam", "Vietnamien", "Hanoï", "Asie"),
    ("Yémen", "Yéménite", "Sanaa", "Asie"),
    ("Zambie", "Zambien", "Lusaka", "Afrique"),
    ("Zimbabwe", "Zimbabwéen", "Harare", "Afrique")
]

# Créer le DataFrame
df_pays = pd.DataFrame(pays_nationalite, columns=["Pays", "Nationalité", "Capitale", "Continent"])

# Afficher le DataFrame
display(df_pays)
# Out:
#                Pays   Nationalité  Capitale        Continent
# 0       Afghanistan        Afghan    Kaboul             Asie
# 1    Afrique du Sud  Sud-africain  Pretoria          Afrique
# 2           Albanie      Albanais    Tirana           Europe
# 3           Algérie      Algérien     Alger          Afrique
# 4         Allemagne      Allemand    Berlin           Europe
# ..              ...           ...       ...              ...
# 154       Venezuela   Vénézuélien   Caracas  Amérique du Sud
# 155        Viêt Nam    Vietnamien     Hanoï             Asie
# 156           Yémen      Yéménite     Sanaa             Asie
# 157          Zambie       Zambien    Lusaka          Afrique
# 158        Zimbabwe    Zimbabwéen    Harare          Afrique
#
# [159 rows x 4 columns]

# %% [markdown]
# ### Extraire les nationalités

# %%
data = pd.read_csv(r'data_cleaned/initial_corpus.csv')
data.head()
# Out:
#                     Journal  \
# 0   Le Figaro, no. 23520
# 1               Le Monde
# 2   Le Figaro (site web)
# 3    Le Monde (site web)
# 4    Le Monde (site web)
#
#                                                Titre        Date  \
# 0                 L'agenda caché de Moscou en Italie  2020-03-30
# 1  Récit   Les trois semaines qui ont chamboulé l...  2020-03-27
# 2  Élargissement de l’Union européenne à l’heure ...  2020-03-26
# 3  Coronavirus : les trois semaines qui ont chamb...  2020-03-26
# 4  Marc Lazar : « Plus l’Italie fait nation face ...  2020-03-25
#
#                                               Auteur  \
# 0                                 Lasserre, Isabelle
# 1  Éric Albert, Cécile Boutelet, Jérôme Gautheret...
# 2                                  Tandonnet, Maxime
# 3  Eric Albert, Jérôme Gautheret, Cécile Boutelet...
# 4                                         Marc Lazar
#
#                                                Texte  \
# 0  LES SYMBOLES comptent parfois plus que les fai...
# 1  Londres, Berlin, Rome et Bruxelles corresponda...
# 2  Fin observateur de la vie politique française ...
# 3  Jeudi 26 mars, les Vingt-Sept doivent se réuni...
# 4  Tribune. L’Italie est le pays qui enregistre à...
#
#                                        extrait_debut  \
# 0   Sur les camions militaires qui, en colonnes, ...
# 1   - Jeudi 26 mars, les Vingt-Sept devaient se r...
# 2  contributeur régulier du FigaroVox, Maxime Tan...
# 3  n visioconférence pour la troisième fois en mo...
# 4   date du 25 mars le plus grand nombre de morts...
#
#                                          extrait_fin CJournal
# 0  Deux semaines pour se ressaisir et s'unir ou p...   Figaro
# 1  pandémie touche tout le monde, indifféremment ...    Monde
# 2  es yeux et de se préparer au changement d’un m...   Figaro
# 3  e la tenue de ses comptes publics, n’est pas s...    Monde
# 4  t de la School of Government de la Luiss (Libr...    Monde

# %%
# Liste des nationalités
nationalites = [
    "Afghan", "Sud-africain", "Albanais", "Algérien", "Allemand", "Andorran", "Angolais", "Antiguais",
    "Saoudien", "Argentin", "Arménien", "Australien", "Autrichien", "Azéri", "Zimbabwéen", "Égyptien",
    "Émirien", "Équatorien", "Érythréen", "Espagnol", "Estonien", "Américain", "Éthiopien", "Fidjien",
    "Finlandais", "Français", "Gabonais", "Gambien", "Géorgien", "Ghanéen", "Grec", "Grenadien",
    "Guatémaltèque", "Guinéen", "Bissau-Guinéen", "Équatoguinéen", "Guyanais", "Haïtien", "Hondurien",
    "Hongrois", "Marshallais", "Indien", "Indonésien", "Irakien", "Iranien", "Irlandais", "Islandais",
    "Israélien", "Italien", "Jamaïcain", "Japonais", "Jordanien", "Kazakh", "Kényan", "Kirghize",
    "Kiribatien", "Koweïtien", "Laotien", "Lesothan", "Letton", "Libanais", "Libérien", "Libyen",
    "Liechtensteinois", "Lituanien", "Luxembourgeois", "Macédonien", "Malgache", "Malaisien", "Malawien",
    "Maldivien", "Malien", "Maltais", "Marocain", "Mauricien", "Mauritanien", "Mexicain", "Micronésien",
    "Moldave", "Monégasque", "Mongol", "Monténégrin", "Mozambicain", "Namibien", "Nauruan", "Népalais",
    "Nicaraguayen", "Nigérien", "Nigérian", "Niuéen", "Norvégien", "Néo-zélandais", "Omanais", "Ougandais",
    "Ouzbek", "Pakistanais", "Palauan", "Panaméen", "Papouan-Néo-Guinéen", "Paraguayen", "Néerlandais",
    "Péruvien", "Philippin", "Polonais", "Portugais", "Qatarien", "Centrafricain", "Congolais", "Dominicain",
    "Tchèque", "Roumain", "Britannique", "Russe", "Rwandais", "Saint-Christophien et Névicien", "Saint-Marinais",
    "Saint-Vincentais et Grenadin", "Saint-Lucien", "Salomonais", "Salvadorien", "Samoan", "Santoméen",
    "Sénégalais", "Serbe", "Seychellois", "Sierra-léonais", "Singapourien", "Slovaque", "Slovène",
    "Somalien", "Soudanais", "Sud-Soudanais", "Sri-lankais", "Suédois", "Suisse", "Surinamien", "Syrien",
    "Swazilandais", "Tadjik", "Tanzanien", "Tchadien", "Thaïlandais", "Est-timorais", "Togolais", "Tongan",
    "Trinidadien", "Tunisien", "Turkmène", "Turc", "Tuvaluan", "Ukrainien", "Uruguayen", "Vanuatuan",
    "Vaticanais", "Vénézuélien", "Vietnamien", "Yéménite", "Zambien", "Zimbabwéen"
]

# Fonction pour générer les différentes formes de nationalités
def generer_formes(nationalite):
    masculin_singulier = nationalite
    masculin_pluriel = nationalite + "s"
    feminin_singulier = nationalite + "e"
    feminin_pluriel = nationalite + "es"
    return masculin_singulier, masculin_pluriel, feminin_singulier, feminin_pluriel

# Création des colonnes avec les différentes formes de nationalités
df_nationalites = pd.DataFrame(nationalites, columns=["Nationalité"])
df_nationalites["Masculin Singulier"], df_nationalites["Masculin Pluriel"], df_nationalites["Féminin Singulier"], df_nationalites["Féminin Pluriel"] = zip(*df_nationalites["Nationalité"].apply(generer_formes))

# Affichage du DataFrame
print(df_nationalites)
# Out:
#       Nationalité Masculin Singulier Masculin Pluriel Féminin Singulier  \
# 0          Afghan             Afghan          Afghans           Afghane
# 1    Sud-africain       Sud-africain    Sud-africains     Sud-africaine
# 2        Albanais           Albanais        Albanaiss         Albanaise
# 3        Algérien           Algérien        Algériens         Algériene
# 4        Allemand           Allemand        Allemands         Allemande
# ..            ...                ...              ...               ...
# 154   Vénézuélien        Vénézuélien     Vénézuéliens      Vénézuéliene
# 155    Vietnamien         Vietnamien      Vietnamiens       Vietnamiene
# 156      Yéménite           Yéménite        Yéménites         Yéménitee
# 157       Zambien            Zambien         Zambiens          Zambiene
# 158    Zimbabwéen         Zimbabwéen      Zimbabwéens       Zimbabwéene
#
#     Féminin Pluriel
# 0          Afghanes
# 1    Sud-africaines
# 2        Albanaises
# 3        Algérienes
# 4        Allemandes
# ..              ...
# 154   Vénézuélienes
# 155    Vietnamienes
# 156      Yéménitees
# 157       Zambienes
# 158    Zimbabwéenes
#
# [159 rows x 5 columns]

# %%
df_nationalites.to_csv('all_nationalities.csv')

# %%
nlp = spacy.load("fr_core_news_sm")

# %%
nationalities = pd.concat([df_nationalites[col].apply(lambda x : x.lower()) for col in df_nationalites.columns]).unique()
def replace_nationality_entities(text):
    doc = nlp(text)
    replaced_text = []
    replaced_words = []  # Nouvelle liste pour stocker les mots remplacés
    for token in doc:
        if token.ent_type_ == "LOC" or token.ent_type_ == "GPE" or str(token).lower() in nationalities:
            replaced_text.append("PAMPLEMOUSSE")
            replaced_words.append(token.text)  # Ajouter le mot remplacé à la liste
        else:
            replaced_text.append(token.text)
    return " ".join(replaced_text), replaced_words

# %%
from tqdm import tqdm

for journal in tqdm(df.CJournal.unique()):
    d = data.loc[data.CJournal == journal].copy()
    d[["texte_processed", "replaced_words"]] = d["Texte"].apply(lambda x: pd.Series(replace_nationality_entities(x)))
    
    display(d.head())
    d.to_csv('data_cleaned/corpus_cleaned_PAMPLEMOUSSE_'+journal+'.csv',sep=";", index=False)
# Out:
#   0%|                                                                                            | 0/6 [00:00<?, ?it/s]
#                      Journal  \
# 0    Le Figaro, no. 23520
# 2    Le Figaro (site web)
# 10   Le Figaro (site web)
# 11   Le Figaro, no. 23505
# 12   Le Figaro (site web)
#
#                                                 Titre        Date  \
# 0                  L'agenda caché de Moscou en Italie  2020-03-30
# 2   Élargissement de l’Union européenne à l’heure ...  2020-03-26
# 10  Coronavirus, un révélateur des faiblesses de l...  2020-03-12
# 11                                            EN BREF  2020-03-12
# 12  Coralie Delaume: «Un choc externe pourrait pro...  2020-03-11
#
#                            Auteur  \
# 0              Lasserre, Isabelle
# 2               Tandonnet, Maxime
# 10  Long, Didier, Laye, Sébastien
# 11                Portes, Thierry
# 12                  Imad, Joachim
#
#                                                 Texte  \
# 0   LES SYMBOLES comptent parfois plus que les fai...
# 2   Fin observateur de la vie politique française ...
# 10  Didier Long est physicien. Sébastien Laye est ...
# 11  Collision entre un navire grec et un patrouill...
# 12  Coralie Delaume est essayiste. Elle a notammen...
#
#                                         extrait_debut  \
# 0    Sur les camions militaires qui, en colonnes, ...
# 2   contributeur régulier du FigaroVox, Maxime Tan...
# 10  repreneur dans l’immobilier, chercheur associé...
# 11   turc Les garde-côtes grecs ont déclaré qu'un ...
# 12  crit Le Couple franco-allemand n’existe pas (M...
#
#                                           extrait_fin CJournal  \
# 0   Deux semaines pour se ressaisir et s'unir ou p...   Figaro
# 2   es yeux et de se préparer au changement d’un m...   Figaro
# 10  faire un choix clair: l’idéologie rigoriste as...   Figaro
# 11  en Afghanistan, ouvrant la voie à des pourparl...   Figaro
# 12  on approche du la fin. De celle de l’Union eur...   Figaro
#
#                                       texte_processed  \
# 0   LES SYMBOLES comptent parfois plus que les fai...
# 2   Fin observateur de la vie politique PAMPLEMOUS...
# 10  Didier Long est physicien . Sébastien Laye est...
# 11  Collision entre un navire PAMPLEMOUSSE et un p...
# 12  Coralie Delaume est essayiste . Elle a notamme...
#
#                                        replaced_words
# 0   [Rome, Bergame, russe, italien, De, Russie, Ch...
# 2   [française, États, l’, Macédoine, du, Nord, Ba...
# 10  [l’, Chine, l’, région, de, Wuhan, l’, l’, Eur...
# 11  [grec, turc, grecs, turc, turc, l', Europe, ru...
# 12  [FIGAROVOX.-, italien, l’, Quelles, l’, l’, l’...
#  17%|█████████████▌                                                                   | 1/6 [14:21<1:11:48, 861.77s/it]
#                    Journal                                              Titre  \
# 1              Le Monde     Récit   Les trois semaines qui ont chamboulé l...
# 3   Le Monde (site web)     Coronavirus : les trois semaines qui ont chamb...
# 4   Le Monde (site web)     Marc Lazar : « Plus l’Italie fait nation face ...
# 5   Le Monde (site web)     Les sept infos non liées au coronavirus que vo...
# 6              Le Monde     Géopolitique | chronique   Nous sommes tous de...
#
#          Date                                             Auteur  \
# 1  2020-03-27  Éric Albert, Cécile Boutelet, Jérôme Gautheret...
# 3  2020-03-26  Eric Albert, Jérôme Gautheret, Cécile Boutelet...
# 4  2020-03-25                                         Marc Lazar
# 5  2020-03-20                                           Le Monde
# 6  2020-03-19                               par Philippe Bernard
#
#                                                Texte  \
# 1  Londres, Berlin, Rome et Bruxelles corresponda...
# 3  Jeudi 26 mars, les Vingt-Sept doivent se réuni...
# 4  Tribune. L’Italie est le pays qui enregistre à...
# 5  On ne peut pas vous reprocher de penser que le...
# 6  Jusqu'à la crise du coronavirus, la liberté de...
#
#                                        extrait_debut  \
# 1   - Jeudi 26 mars, les Vingt-Sept devaient se r...
# 3  n visioconférence pour la troisième fois en mo...
# 4   date du 25 mars le plus grand nombre de morts...
# 5  nde s’est arrêté de tourner à cause de l’épidé...
# 6  anchir librement les frontières, de sillonner ...
#
#                                          extrait_fin CJournal  \
# 1  pandémie touche tout le monde, indifféremment ...    Monde
# 3  e la tenue de ses comptes publics, n’est pas s...    Monde
# 4  t de la School of Government de la Luiss (Libr...    Monde
# 5   véritable monde alternatif, serein et chaleur...    Monde
# 6  our les malheureux jetés sur les routes de l'e...    Monde
#
#                                      texte_processed  \
# 1  PAMPLEMOUSSE , PAMPLEMOUSSE , PAMPLEMOUSSE et ...
# 3  Jeudi 26   mars , les PAMPLEMOUSSE doivent se ...
# 4  Tribune . L’ PAMPLEMOUSSE est le pays qui enre...
# 5  On ne peut pas vous reprocher de penser que le...
# 6  Jusqu' à la crise du coronavirus , la liberté ...
#
#                                       replaced_words
# 1  [Londres, Berlin, Rome, Bruxelles, corresponda...
# 3  [Vingt-Sept, Europe, l’, Suède, l’, l’, sacro,...
# 4  [Italie, Italiens, non-Italiens, Français, Ita...
# 5  [l’, britanniques, Bonn, Rhénanie-du-Nord, -, ...
# 6  [français, indien, malien, l', Europe, la, Fra...
#  33%|███████████████████████████▋                                                       | 2/6 [27:24<54:20, 815.16s/it]
#                       Journal  \
# 8    Libération (site web)
# 16   Libération (site web)
# 22   Libération (site web)
# 27   Libération (site web)
# 28              Libération
#
#                                                 Titre        Date  \
# 8            Schengen, l'autre victime du coronavirus  2020-03-19
# 16  Erdogan réclame plus de soutien de l'UE et de ...  2020-03-09
# 22  Crise des migrants : les Vingt-sept haussent l...  2020-03-05
# 27  Mobilisation après le 49.3,  crise des migrant...  2020-03-02
# 28         «Dans le voyage, il y a désidentification»  2020-02-29
#
#                                                Auteur  \
# 8                                     Boris Grésillon
# 16                                                AFP
# 22                                     Jean Quatremer
# 27                                         LIBERATION
# 28  Recueilli par Guillaume Lecaplain Envoyé spéci...
#
#                                                 Texte  \
# 8   Bien que le Covid-19 se joue des frontières, l...
# 16  Le président turc Recep Tayyip Erdogan a récla...
# 22  Mercredi, les ministres de l'intérieur de l'Un...
# 27  L'essentiel de l'actualité    49.3. Le gouvern...
# 28  O n boit un thé un peu trop infusé dans une cu...
#
#                                         extrait_debut  \
# 8   onde s'hérisse de barrières. Ce paradoxe souli...
# 16  lundi lors d'une visite à Bruxelles un soutien...
# 22  , convoqués à Bruxelles ont rejeté le «chantag...
# 27  nt ayant coupé court au débat parlementaire en...
# 28  ne beaucoup trop ensoleillée pour la saison. M...
#
#                                           extrait_fin    CJournal  \
# 8   résillon professeur de géographie à Aix-Marsei...  Libération
# 16  rs d'une conférence de presse conjointe avec l...  Libération
# 22  Grèce des moyens de surveillance et l'Union va...  Libération
# 27  ent tendu entre Nétanyahou et son rival Benny ...  Libération
# 28  xpérience d'un autre que je suis. C'est au mie...  Libération
#
#                                       texte_processed  \
# 8   Bien que le Covid-19 se joue des frontières , ...
# 16  Le président PAMPLEMOUSSE Recep Tayyip Erdogan...
# 22  Mercredi , les ministres de l' intérieur de l'...
# 27  L' essentiel de l' actualité     49.3 . Le gou...
# 28  O n boit un thé un peu trop infusé dans une cu...
#
#                                        replaced_words
# 8   [Tribune, Etats-Unis, Vingt-Sept, Italie, Slov...
# 16              [turc, Bruxelles, Syrie, turc, Union]
# 22  [Bruxelles, turc, Bruxelles, turc, Turquie, Un...
# 27  [Paris, République, Europe, Lesbos, grecs, mar...
# 28  [algérien, Lesbos, Bayonne, Bayonne, Capes, Mé...
#  50%|█████████████████████████████████████████▌                                         | 3/6 [32:11<28:41, 573.98s/it]
#                     Journal  \
# 13   La Croix (site web)
# 18   La Croix (site web)
# 70   La Croix (site web)
# 78   La Croix (site web)
# 79   La Croix (site web)
#
#                                                 Titre        Date  \
# 13  Crise migratoire?: bras de fer autour de la fr...  2020-03-11
# 18  Un projet européen pour accueillir 1 500 enfan...  2020-03-09
# 70     Hongrie?: Viktor Orban champion de la natalité  2019-09-06
# 78  En février 2020, une rencontre inédite des évê...  2019-08-21
# 79     Crise des migrants ou crise de la solidarité??  2019-08-19
#
#                                   Auteur  \
# 13                         Marie Verdier
# 18                         Pierre Cochez
# 70                    François d'Alançon
# 78  Mélinée Le Priol (avec Vatican News)
# 79                  Florence Montreynaud
#
#                                                 Texte  \
# 13  Après la visite du président turc Recep Tayyip...
# 18  Face aux conditions de vie précaires des migra...
# 70  Analyse\n      \n        \n      Le premier mi...
# 78  Pour la première fois, les évêques des pays du...
# 79  Tribune\n      \n        \n      La France doi...
#
#                                         extrait_debut  \
# 13  dogan à Bruxelles, lundi 9 mars, Emmanuel Macr...
# 18   dans les îles grecques, l'Allemagne prend la ...
# 70   hongrois a invoqué la théorie complotiste d'e...
# 78  urtour méditerranéen vont se réunir du 18 au 2...
# 79  eillir dignement des réfugiés. C'est notre dev...
#
#                                           extrait_fin CJournal  \
# 13  nement pour faire face à l'afflux migratoire e...    Croix
# 18   prévoyant que les migrants restent en Turquie...    Croix
# 70  eurs parents ayant jugé préférable d'avoir des...    Croix
# 78  re et la perception qu'en a l'opinion publique...    Croix
# 79  leur humanité.   Bienvenue en France?!   (1) D...    Croix
#
#                                       texte_processed  \
# 13  Après la visite du président PAMPLEMOUSSE Rece...
# 18  Face aux conditions de vie précaires des migra...
# 70  Analyse \n      \n        \n       Le premier ...
# 78  Pour la première fois , les évêques des pays d...
# 79  Tribune \n      \n        \n       La France d...
#
#                                        replaced_words
# 13  [turc, Bruxelles, allemande, Ankara, Combien, ...
# 18  [Allemagne, allemand, Paris, Grèce, Allemagne,...
# 70  [hongrois, Budapest, hongrois, Brésil, États-U...
# 78  [Bari, Pouilles, Turquie, Espagne, Grèce, Liby...
# 79  [France, Afghanistan, Syrie, Soudan, Banglades...
#  67%|███████████████████████████████████████████████████████▎                           | 4/6 [35:27<14:09, 424.66s/it]
#                      Journal  \
# 15   Les Echos, no. 23154
# 17   Les Echos (site web)
# 24   Les Echos (site web)
# 29   Les Echos, no. 23140
# 35   Les Echos (site web)
#
#                                                 Titre        Date  \
# 15  Erdogan à Bruxelles pour démêler la  crise des...  2020-03-09
# 17  Migrants : l'Europe propose d'accueillir 1.500...  2020-03-09
# 24     BHL : « Cette société française me fait peur »  2020-03-05
# 29  L'Union européenne renforce sa surveillance de...  2020-02-18
# 35  A Paris, Anne Hidalgo lance sa campagne tambou...  2020-01-13
#
#                           Auteur  \
# 15          CATHERINE CHATIGNOUX
# 17                     LES ECHOS
# 24  DANIEL FORTIN; NICOLAS BARRE
# 29               YVES BOURDILLON
# 35              LAURENT THEVENIN
#
#                                                 Texte  \
# 15  Samedi, Recep Tayyip Erdogan semblait jouer l'...
# 17  Situation ultra-tendue en Grèce. Lescamps de r...
# 24  Vous avez entrepris, depuis quelques semaines,...
# 29  L'Europe va renforcer sa lutte contre le trafi...
# 35  La machine est lancée. Candidate depuis ce wee...
#
#                                         extrait_debut  \
# 15  almie. «  Sur ordre du président  [...]  aucun...
# 17  giés surpeuplés et les conditions de vie de pl...
# 24   vous rendre sur plusieurs théâtres de conflit...
# 29  'armes en Libye. Le Conseil des ministres des ...
# 35  nd à sa réélection comme maire de Paris en mar...
#
#                                           extrait_fin CJournal  \
# 15  Union européenne. II a jusqu'ici refusé les 50...    Echos
# 17   de sécurité, de stabilité dans la région et d...    Echos
# 24  es crimes de la bande à Baader. Jürgen Haberma...    Echos
# 29  pération Sophia, lancée en 2015 au plus fort d...    Echos
# 35  ati, la candidate Les Républicains (17 %), Ben...    Echos
#
#                                       texte_processed  \
# 15  Samedi , Recep Tayyip Erdogan semblait jouer l...
# 17  Situation ultra-tendue en PAMPLEMOUSSE . Lesca...
# 24  Vous avez entrepris , depuis quelques semaines...
# 29  PAMPLEMOUSSE PAMPLEMOUSSE va renforcer sa lutt...
# 35  La machine est lancée . Candidate depuis ce we...
#
#                                        replaced_words
# 15  [mer, Egée, Turquie, Lesbos, Samos, grec, Grèc...
# 17  [Grèce, Europe, allemand, Allemagne, Grèce, Al...
# 24  [Paris, -, Match, Nigeria, Kurdistan, syrien, ...
# 29  [L', Europe, Libye, Libye, Turquie, Tripoli, E...
# 35  [Paris, porte, de, la, Chapelle, Parisien, Par...
#  83%|█████████████████████████████████████████████████████████████████████▏             | 5/6 [40:11<06:13, 373.97s/it]
#                        Journal  \
# 26               Le Parisien
# 36               Le Parisien
# 52   Le Parisien (site web)
# 64               Le Parisien
# 65               Le Parisien
#
#                                                 Titre        Date  \
# 26  Syrie, un cauchemar sans fin  Des milliers de ...  2020-03-03
# 36     Par Marie-Anne Gairaud Et aussi D'incidents en  2019-12-18
# 52  Municipales à Paris : Danielle Simonnet veut a...  2019-10-24
# 64  A la biennale, les portraits font bonne figure...  2019-09-11
# 65  Nager pour ne pas couler  « WELCOME », de Phil...  2019-09-10
#
#                                   Auteur  \
# 26                                   NaN
# 36                    Marie-Anne Gairaud
# 52  Marie-Anne Gairaud et Nicolas Maviel
# 64                                   NaN
# 65                                  S.T.
#
#                                                 Texte  \
# 26  Par Henri Vernet     Il aura fallu que l'Europ...
# 36  Par Marie-Anne Gairaud   Et aussi   D'incident...
# 52  Le mouvement La France Insoumise l'a désignée ...
# 64  Issy-les-Moulineaux   Par Estelle Dautry   Des...
# 65  vvvv   « WELCOME »   20 h 55 (1 h 50).   de Ph...
#
#                                         extrait_debut  \
# 26  ue l'Europe se retrouve à nouveau sous la pres...
# 36  n incidence ?   C'est peu dire que la mandatur...
# 52  f de file mais elle est prête à renoncer à bri...
# 64  otos réalisées par David Lynch - qui a été élè...
# 65  ppe Lioret, avec Vincent Lindon (photo), Firat...
#
#                                           extrait_fin  CJournal  \
# 26   et Macron sur la frontière turque, un peu à l...  Parisien
# 36  inimise aujourd'hui cette crise : « Ils étaien...  Parisien
# 52  c une vraie urgence sociale et écologique à re...  Parisien
# 64  rtrait à l'oeuvre. « Il nous faut du wi-fi pou...  Parisien
# 65  héroïsme ordinaire. Tout, ici, sonne vrai. Jus...  Parisien
#
#                                       texte_processed  \
# 26  Par Henri Vernet      Il aura fallu que PAMPLE...
# 36  Par Marie-Anne Gairaud    Et aussi    D' incid...
# 52  Le mouvement La France Insoumise l' a désignée...
# 64  PAMPLEMOUSSE    Par Estelle Dautry    Des phot...
# 65  vvvv    « WELCOME »    20 h 55 ( 1 h 50 ) .   ...
#
#                                        replaced_words
# 26  [l', Europe, Syrie, région, d', Idlib, Françai...
# 36  [Paris, Paris, la, Ville, La, Ville, La, Ville...
# 52  [Paris, Paris, Capitale, XXe, Paris, Paris, bâ...
# 64  [Issy-les-Moulineaux, Beaux, -, arts, Sculptur...
# 65  [France, Welcome, piscine, de, Calais, Manche,...
# 100%|███████████████████████████████████████████████████████████████████████████████████| 6/6 [42:19<00:00, 423.28s/it]

# %%
final = pd.concat([
    pd.read_csv('data_cleaned/corpus_cleaned_PAMPLEMOUSSE_Figaro.csv',sep=";"),
    pd.read_csv('data_cleaned/corpus_cleaned_PAMPLEMOUSSE_Monde.csv',sep=";"),
    pd.read_csv('data_cleaned/corpus_cleaned_PAMPLEMOUSSE_Libération.csv',sep=";"),
    pd.read_csv('data_cleaned/corpus_cleaned_PAMPLEMOUSSE_Croix.csv',sep=";"),
    pd.read_csv('data_cleaned/corpus_cleaned_PAMPLEMOUSSE_Parisien.csv',sep=";"),
    pd.read_csv('data_cleaned/corpus_cleaned_PAMPLEMOUSSE_Echos.csv',sep=";")
])

# %%
final.to_csv('data_cleaned/corpus_cleaned_PAMPLEMOUSSE.csv',sep=";", index=False)

# %%
data[["Texte","texte_processed","replaced_words"]].to_excel('test_replace_v3.xlsx')
# Out:
# <ipython-input-94-c96f84ad0861>:1: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.2.9' currently installed).
#   data[["Texte","texte_processed","replaced_words"]].to_excel('test_replace_v3.xlsx')

# %% [markdown]
# ### Etude des mots retirés

# %%
from tqdm import tqdm
words = {}

for row in tqdm(final.replaced_words) :
    row_formated = row[1:-1].replace("'","").replace('"','').split(',')
    for word in row_formated :
        if word.lower() not in words.keys() :
            words[word.lower()] = 1
        else :
            words[word.lower()] += 1
words
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 3030/3030 [00:00<00:00, 14111.31it/s]
# {'rome': 7,
#  ' bergame': 4,
#  ' russe': 440,
#  ' italien': 363,
#  ' de': 1210,
#  ' russie': 813,
#  ' chine': 313,
#  ' l': 3766,
#  ' italie': 1213,
#  ' russes': 337,
#  ' kremlin': 101,
#  ' libye': 332,
#  ' moscou': 266,
#  ' état': 1609,
#  ' rossiya': 1,
#  ' 1': 2,
#  ' europe': 5743,
#  ' états-unis': 805,
#  ' la': 2874,
#  ' français': 1914,
#  ' allemagne': 2770,
#  ' autriche': 446,
#  ' pays': 274,
#  ' -': 2053,
#  ' bas': 150,
#  ' vingt-sept': 50,
#  'française': 30,
#  ' états': 839,
#  ' l’': 1781,
#  ' macédoine': 110,
#  ' du': 529,
#  ' nord': 315,
#  ' balkans': 339,
#  ' espagne': 372,
#  ' france': 3791,
#  ' membres': 172,
#  ' bruxelles': 873,
#  ' brexit': 455,
#  ' qu’': 190,
#  ' nul': 1,
#  ' n’': 13,
#  'l’': 23,
#  ' région': 33,
#  ' wuhan': 6,
#  ' française': 624,
#  ' allemands': 524,
#  ' japon': 48,
#  ' israël': 64,
#  ' singapour': 9,
#  ' corée': 53,
#  ' sud': 172,
#  ' italiens': 198,
#  ' s’': 146,
#  ' aggrave': 1,
#  ' européens': 672,
#  'grec': 20,
#  ' turc': 477,
#  ' grecs': 148,
#  ' britannique': 414,
#  ' megxit': 1,
#  ' kaboul': 114,
#  ' afghan': 66,
#  'figarovox.-': 7,
#  ' quelles': 39,
#  ' rome': 218,
#  ' monti': 1,
#  ' allemande': 754,
#  ' washington': 159,
#  ' pékin': 57,
#  ' empire': 38,
#  ' milieu': 1,
#  ' république': 308,
#  ' fédérale': 28,
#  ' el': 56,
#  ' khomri': 12,
#  ' hollande': 216,
#  ' turquie': 1887,
#  ' d’': 45,
#  ' syrie': 1172,
#  ' grèce': 1346,
#  ' troïka': 2,
#  ' grec': 282,
#  ' ne': 1,
#  ' chios': 29,
#  ' lesbos': 174,
#  'turc': 24,
#  ' ankara': 488,
#  ' syriens': 753,
#  ' idleb': 43,
#  ' syrien': 408,
#  'vieux': 9,
#  ' continent': 85,
#  ' terre': 24,
#  ' combien': 20,
#  ' constantinople': 7,
#  'idlib': 1,
#  ' iran': 215,
#  ' idlib': 55,
#  ' turcs': 273,
#  ' a': 39,
#  ' voir': 14,
#  ' allemand': 614,
#  ' l?exemple': 1,
#  ' ?': 2,
#  ' afghans': 276,
#  ' irakiens': 113,
#  ' moyen-orient': 193,
#  ' damas': 106,
#  ' américain': 485,
#  ' t’': 2,
#  ' munich': 86,
#  ' usa': 8,
#  ' erdogan': 31,
#  ' kurdes': 43,
#  ' bulgarie': 111,
#  ' égypte': 52,
#  ' arabie': 79,
#  ' saoudite': 74,
#  ' émirats': 24,
#  ' istanbul': 85,
#  ' africains': 61,
#  ' le': 90,
#  ' cerf': 2,
#  ' arabes': 20,
#  ' unis': 21,
#  ' bosnie': 25,
#  ' bachar': 35,
#  ' saoudiens': 25,
#  ' mali': 86,
#  ' chaîne': 9,
#  ' sahel': 48,
#  ' adra': 1,
#  ' méditerranée': 500,
#  ' j’': 28,
#  'bonjour': 2,
#  ' paris': 1171,
#  ' marseille': 72,
#  ' lyon': 45,
#  ' saint-brieuc': 2,
#  ' saint-dizier': 2,
#  ' aurillac': 3,
#  ' montluçon': 1,
#  ' angers': 3,
#  ' signes': 1,
#  ' var': 5,
#  ' samedi': 14,
#  ' carcassonne': 4,
#  ' beltrame': 2,
#  ' tulle': 1,
#  ' fontainebleau': 2,
#  ' cahors': 1,
#  ' lons-le-saunier': 1,
#  ' écrites': 1,
#  ' espagnols': 53,
#  ' polonais': 298,
#  ' neuf': 3,
#  ' occidentaux': 6,
#  ' marginalisés': 1,
#  ' urgo': 2,
#  ' belote': 1,
#  ' conseil': 12,
#  ' régional': 10,
#  ' île-de-france': 35,
#  'grèce': 49,
#  ' frans': 2,
#  ' glasgow': 7,
#  ' madrid': 66,
#  ' pologne': 667,
#  ' polonaises': 14,
#  'l': 141,
#  ' province': 8,
#  ' d': 238,
#  ' amérique': 227,
#  ' port': 39,
#  ' antalya': 7,
#  ' gaza': 9,
#  ' israéliens': 10,
#  ' afghanistan': 304,
#  'français': 122,
#  ' union': 262,
#  ' vieux': 90,
#  ' varsovie': 147,
#  ' élysée': 199,
#  ' occident': 195,
#  ' est': 250,
#  ' budapest': 117,
#  ' albanie': 72,
#  ' macron': 106,
#  ' versailles': 29,
#  ' américains': 304,
#  ' prague': 34,
#  ' tchèque': 188,
#  'turquie': 61,
#  ' instagram': 18,
#  ' afghane': 52,
#  ' berlin': 793,
#  ' iraniens': 55,
#  ' kastellorizo': 1,
#  ' maku_marz': 1,
#  ' maku': 1,
#  ' serbie': 202,
#  ' ville': 46,
#  ' lumière': 4,
#  ' macdonald': 1,
#  ' aubervilliers': 13,
#  ' parisiens': 18,
#  ' bisbilles': 1,
#  ' macronie': 4,
#  ' samos': 36,
#  ' lumières': 1,
#  ' ouest': 211,
#  ' hongrie': 669,
#  ' lituanien': 16,
#  'nice': 2,
#  ' cour': 52,
#  ' nice': 48,
#  ' aix-en-provence': 2,
#  ' bouches-du-rhône': 10,
#  ' toulon': 9,
#  ' nantes': 31,
#  'hongrois': 18,
#  ' tusnadfürdö': 1,
#  ' hongroise': 103,
#  ' sourdement': 1,
#  ' krastev': 1,
#  ' holmes': 1,
#  ' orban': 95,
#  ' charybde': 2,
#  'pologne': 8,
#  ' lacanau': 1,
#  ' basée': 1,
#  ' luxembourg': 70,
#  ' etat': 288,
#  'pas-de-calais': 5,
#  ' c’': 9,
#  ' tunnel': 32,
#  ' sous': 32,
#  ' manche': 120,
#  ' calais': 680,
#  ' angleterre': 152,
#  ' les': 41,
#  ' projets': 1,
#  ' pour': 8,
#  ' londres': 243,
#  ' ferroviaire': 1,
#  ' folkestone': 3,
#  ' kent': 6,
#  ' coquelles': 17,
#  ' pas-de-calais': 61,
#  ' léviathan': 1,
#  ' centre': 39,
#  ' safe': 1,
#  ' casques': 13,
#  ' eurotunnel': 31,
#  ' sangatte': 10,
#  ' channel': 5,
#  ' sentinelle': 8,
#  ' parafe': 1,
#  ' royaume': 511,
#  ' uni': 514,
#  'retour': 1,
#  ' zombieland': 1,
#  ' carpates': 2,
#  ' irlandais': 23,
#  ' roumanie': 68,
#  ' browning': 4,
#  ' herzog': 1,
#  ' hollywood': 15,
#  ' apaches': 1,
#  ' libido': 1,
#  ' feuillade': 1,
#  ' belgique': 126,
#  ' mexique': 160,
#  ' philippines': 7,
#  ' vampires': 2,
#  ' xiie': 2,
#  ' réunion': 3,
#  ' musées': 1,
#  ' nationaux': 2,
#  ' grand': 26,
#  ' palais': 46,
#  'la': 115,
#  ' afrique': 519,
#  ' faut': 7,
#  ' portugal': 60,
#  ' croatie': 121,
#  ' estonie': 22,
#  ' lituanie': 83,
#  ' albanais': 44,
#  ' géorgiens': 15,
#  ' libyens': 47,
#  ' sub-sahariens': 4,
#  ' providence': 21,
#  ' état(ame': 1,
#  ' ruée': 4,
#  ' sahara': 37,
#  ' grande-bretagne': 299,
#  ' xxe': 37,
#  'allemagne': 131,
#  ' dresde': 49,
#  ' saxe': 84,
#  ' chemnitz': 30,
#  ' repris': 1,
#  ' christian': 2,
#  'état': 44,
#  ' nation': 23,
#  ' matignon': 30,
#  'de': 22,
#  ' californie': 22,
#  ' etats-unis': 179,
#  ' centrale': 44,
#  ' trump': 46,
#  ' oakland': 1,
#  ' san': 20,
#  ' francisco': 8,
#  ' arizona': 12,
#  ' nouveau': 4,
#  ' texas': 48,
#  ' suprême': 33,
#  'yamit': 1,
#  ' sinaï': 4,
#  ' perpignan': 8,
#  ' solidarnosc': 4,
#  ' salvador': 18,
#  ' visa': 1,
#  ' chauvel': 1,
#  ' hongrois': 292,
#  ' slovaquie': 153,
#  ' arméniens': 19,
#  ' gdansk': 2,
#  'carnival': 1,
#  ' raw': 1,
#  ' burgue': 1,
#  ' chernobyl': 1,
#  'athènes': 7,
#  ' exarchia': 3,
#  ' athènes': 233,
#  ' skaï': 1,
#  'chantilly': 1,
#  ' château': 14,
#  ' chantilly': 1,
#  ' ier': 2,
#  ' autodidacte': 1,
#  ' laurel': 2,
#  ' rue': 24,
#  ' saint-honoré': 1,
#  ' saint-cloud': 4,
#  ' festival': 2,
#  ' rock': 3,
#  ' seine': 16,
#  ' bagarre': 1,
#  ' biche': 1,
#  ' ixe': 2,
#  ' arrondissement': 22,
#  ' drouot': 1,
#  ' babel': 4,
#  ' bordello': 1,
#  ' novelty': 1,
#  ' ferme': 1,
#  ' bonheur': 1,
#  ' avenue': 6,
#  ' nanterre': 4,
#  'xxe': 1,
#  ' fédération': 6,
#  ' new': 105,
#  ' york': 98,
#  ' novitchok': 2,
#  ' britanniques': 271,
#  ' skripal': 3,
#  ' néerlandais': 79,
#  ' \\xa0': 22,
#  ' haye': 5,
#  ' suisse': 98,
#  ' lausanne': 1,
#  ' berne': 4,
#  ' géorgie': 29,
#  ' sorbonne': 24,
#  ' russian': 1,
#  ' political': 1,
#  ' war': 1,
#  ' tallinn': 6,
#  ' maïdan': 2,
#  ' ukraine': 383,
#  ' crimée': 56,
#  ' donbass': 21,
#  ' spetsnaz': 1,
#  ' ukrainiens': 71,
#  ' kiev': 44,
#  ' donetsk': 8,
#  ' ukrainien': 70,
#  ' saint-pétersbourg': 7,
#  ' graphika': 1,
#  ' américaine': 274,
#  ' russiagate': 1,
#  ' roumain': 7,
#  ' pro-trump': 2,
#  ' catalogne': 18,
#  ' suède': 319,
#  ' sputnik': 1,
#  ' françaises': 154,
#  ' rt': 1,
#  ' turla': 4,
#  ' pentagone': 31,
#  'américain': 39,
#  ' mexicaine': 44,
#  ' guatemala': 27,
#  ' honduras': 17,
#  ' affamés': 2,
#  '     ': 23,
#  ' «': 7,
#  ' mississippi': 4,
#  ' mexicains': 25,
#  ' mexicaines': 6,
#  ' maison': 109,
#  ' blanche': 142,
#  ' paso': 11,
#  ' américaines': 118,
#  ' canton': 5,
#  'américaines': 3,
#  ' cbp': 2,
#  ' yuma': 1,
#  ' guatémaltèque': 1,
#  'amérique': 8,
#  ' mexicain': 27,
#  ' aéroport': 42,
#  ' mexico': 10,
#  'etats-unis': 5,
#  ' centraméricains': 3,
#  ' venezuela': 76,
#  'américains': 4,
#  ' jacumba': 1,
#  ' camp': 9,
#  ' pendleton': 1,
#  ' diego': 6,
#  ' contacté': 6,
#  ' marines': 1,
#  'libye': 15,
#  ' malte': 99,
#  'département': 1,
#  ' sécurité': 8,
#  ' intérieure': 8,
#  ' donna': 1,
#  ' tornillo': 1,
#  ' laredo': 1,
#  ' surpopulation': 1,
#  ' rio': 26,
#  ' grande': 31,
#  's’': 2,
#  ' rfa': 10,
#  ' francophone': 1,
#  ' présidence': 2,
#  'lampedusa': 4,
#  ' sicile': 58,
#  ' agrigente': 5,
#  ' corse': 27,
#  ' schengen': 658,
#  ' lampedusa': 50,
#  'paris': 59,
#  ' davantage': 1,
#  ' dialogues': 2,
#  ' luiss': 2,
#  'mairie': 1,
#  ' jean-quarré': 5,
#  ' porte': 25,
#  ' chapelle': 26,
#  ' singa': 9,
#  ' mairie': 13,
#  'france': 54,
#  ' chypre': 72,
#  ' valette': 19,
#  ' sibiu': 1,
#  ' alliance': 8,
#  ' portugais': 19,
#  ' nicosie': 6,
#  ' signataires': 3,
#  'europe': 106,
#  ' mon': 1,
#  ' remainers': 2,
#  ' brexiters': 2,
#  ' communauté': 14,
#  ' deauville': 2,
#  ' irlande': 71,
#  'marrakech': 3,
#  ' marrakech': 7,
#  ' maroc': 157,
#  'schengen': 19,
#  ' luxembourgeoise': 10,
#  ' meaux': 1,
#  ' pilier': 1,
#  ' séville': 3,
#  ' stockholm': 21,
#  ' rétablissons': 2,
#  ' disposez': 1,
#  ' musée': 19,
#  ' juif': 4,
#  ' mehdi': 1,
#  ' nemmouche': 1,
#  '  ': 74,
#  ' bordeaux': 28,
#  ' constitutionnel': 5,
#  ' bordelais': 1,
#  ' opéra': 10,
#  ' indien': 15,
#  ' cachemire': 5,
#  ' yazidis': 1,
#  ' califat': 2,
#  ' ei': 86,
#  ' macan': 1,
#  ' ligues': 2,
#  'philharmonia': 1,
#  ' kepler(s': 2,
#  ' floride': 17,
#  ' braquo': 1,
#  ' broadchurch': 2,
#  ' happy': 1,
#  ' valley': 7,
#  'vie': 1,
#  ' braquet': 1,
#  ' autolib': 3,
#  ' halles': 2,
#  ' salvini': 12,
#  ' isolée': 5,
#  ' koffi': 8,
#  ' notre-dame-des-landes': 14,
#  ' vod': 1,
#  ' fifi': 1,
#  ' splendid': 1,
#  ' clavier': 1,
#  ' chinon': 6,
#  ' châteaux': 3,
#  ' loire': 24,
#  ' chenonceau': 2,
#  ' val': 6,
#  ' épinal': 5,
#  ' chinonais': 2,
#  ' saumur': 2,
#  ' mêmes': 4,
#  ' orgeval': 2,
#  ' yvelines': 10,
#  ' multigénérationnelle': 1,
#  ' chao': 2,
#  ' ling': 2,
#  ' ivoiriens': 9,
#  ' verneuil': 2,
#  ' baryton': 1,
#  ' kaïras': 1,
#  ' bo': 1,
#  ' qu': 1,
#  ' ducobu': 1,
#  ' laure': 1,
#  ' rueil': 1,
#  ' malmaison': 1,
#  ' parisien': 12,
#  ' indre-et-loire': 2,
#  ' asiatique': 1,
#  'figaro.-': 2,
#  ' couvent': 1,
#  ' saint-marc': 1,
#  ' florence': 6,
#  ' italiennes': 1,
#  ' irak': 301,
#  ' iranien': 48,
#  ' asie': 88,
#  ' caucase': 7,
#  ' baltes': 10,
#  ' finlande': 48,
#  'états-unis': 23,
#  ' new-york': 9,
#  ' outre-atlantique': 14,
#  ' janvier': 1,
#  ' los': 11,
#  ' angeles': 11,
#  ' tunisie': 62,
#  ' charlie': 2,
#  ' hypercacher': 1,
#  ' islamique': 54,
#  ' strasbourg': 73,
#  ' trump-': 1,
#  ' musulmans': 1,
#  ' us': 3,
#  ' resnais': 1,
#  ' barcelone': 35,
#  ' réponse': 6,
#  ' budget': 4,
#  ' vécue': 1,
#  ' aix-la-chapelle': 3,
#  'équateur': 1,
#  ' vénézuéliens': 48,
#  ' vice-ministre': 3,
#  ' mobilité': 1,
#  ' humaine': 2,
#  ' argentine': 18,
#  ' brésil': 35,
#  ' bolivie': 6,
#  ' colombie': 44,
#  ' costa': 15,
#  ' rica': 13,
#  ' chili': 19,
#  ' panama': 16,
#  ' paraguay': 5,
#  ' pérou': 18,
#  ' dominicaine': 4,
#  ' uruguay': 3,
#  ' équateur': 10,
#  'balkans': 11,
#  ' pristina': 4,
#  ' kosovo': 58,
#  ' serbes': 21,
#  ' belgrade': 24,
#  ' serbe': 66,
#  ' monténégro': 26,
#  ' republika': 1,
#  ' srpska': 1,
#  ' des': 92,
#  ' passée': 1,
#  ' danemark': 167,
#  ' viktor': 5,
#  ' lettonie': 34,
#  ' australie': 60,
#  ' slovénie': 111,
#  ' ottawa': 9,
#  ' déclenchée': 1,
#  ' conçue': 3,
#  'allemande': 75,
#  ' affaiblie': 8,
#  ' düsseldorf': 8,
#  'mont-saint-aignan': 1,
#  ' maritime': 7,
#  ' emblématiques': 1,
#  ' bonald': 1,
#  ' bénouville': 2,
#  ' leclerc': 1,
#  ' romantisme': 1,
#  ' roque': 1,
#  ' timor': 3,
#  ' oriental': 4,
#  ' major': 5,
#  ' regardez': 19,
#  ' combourg': 1,
#  ' vichy': 5,
#  ' trocadéro': 2,
#  ' maastricht': 28,
#  ' arc': 6,
#  ' triomphe': 7,
#  ' champs': 13,
#  ' élysées': 11,
#  ' hostilité': 1,
#  ' ottoman': 17,
#  ' habsbourg': 1,
#  'russie': 16,
#  ' qing': 2,
#  ' cuba': 41,
#  ' nicaragua': 9,
#  ' alpes': 78,
#  ' bavière': 174,
#  ' hesse': 8,
#  ' passons': 1,
#  ' sao': 1,
#  ' paulo': 1,
#  ' middle': 1,
#  ' west': 1,
#  ' haut': 11,
#  ' adige': 1,
#  ' étonnez': 1,
#  ' ajoutez': 3,
#  ' observatoire': 9,
#  ' christ': 1,
#  ' jésus': 1,
#  ' françallemagne': 3,
#  ' place': 43,
#  ' grands': 3,
#  ' hommes': 1,
#  ' petit': 4,
#  ' biscuit': 1,
#  ' halle': 5,
#  ' tony': 1,
#  ' garnier': 1,
#  ' stade': 21,
#  ' 2': 5,
#  '    ': 17,
#  ' brésiliens': 4,
#  ' land': 51,
#  ' landtag': 1,
#  'bavière': 3,
#  ' anti-merkel': 9,
#  ' maghreb': 37,
#  ' algérie': 65,
#  ' cologne': 98,
#  ' tunisien': 19,
#  ' anis': 7,
#  ' amri': 6,
#  ' virage': 1,
#  ' brandebourg': 11,
#  ' kauder': 1,
#  ' afd': 15,
#  ' jubile': 1,
#  'astral': 1,
#  ' érythréen': 6,
#  ' espagnole': 77,
#  ' astral': 1,
#  'aquarius': 9,
#  ' génération.s': 3,
#  ' pyrénées': 19,
#  ' aquarius': 84,
#  ' provence': 18,
#  ' côte': 48,
#  ' azur': 17,
#  ' maritimes': 42,
#  'marseille': 7,
#  ' bfmtv': 1,
#  'maine-et-loire': 1,
#  ' maine-et-loire': 2,
#  ' wall': 7,
#  ' street': 22,
#  ' autrichien': 111,
#  ' institut': 36,
#  ' montaigne': 6,
#  ' jusque': 4,
#  'caracas': 1,
#  ' caraïbes': 7,
#  ' uruguayen': 1,
#  ' cúcuta': 1,
#  ' vénézuélien': 15,
#  ' onze': 1,
#  ' caracas': 14,
#  ' haute-vienne': 3,
#  'place': 4,
#  ' stortorget': 1,
#  ' helsingborg': 6,
#  ' suédois': 80,
#  ' scanie': 3,
#  ' malmö': 13,
#  ' göteborg': 14,
#  ' suédoise': 48,
#  ' ann': 2,
#  ' cathrine': 2,
#  ' jungar': 2,
#  ' détroit': 5,
#  ' oresund': 2,
#  ' folketing': 1,
#  ' libéraux': 5,
#  ' pernille': 1,
#  ' vermund': 1,
#  ' norvège': 58,
#  ' norvégien': 13,
#  ' oslo': 5,
#  ' arménien': 25,
#  ' mer': 188,
#  ' hagen': 1,
#  ' listhaug': 2,
#  ' norvégiens': 4,
#  ' utoya': 1,
#  ' président': 3,
#  'escp': 1,
#  ' grub': 1,
#  ' siemens': 2,
#  ' görlitz': 1,
#  ' polonaise': 89,
#  ' ligne': 25,
#  ' anti-euro': 1,
#  ' soudan': 37,
#  ' ofpra': 116,
#  ' dublin': 127,
#  ' lr': 15,
#  ' françois': 9,
#  ' noël': 4,
#  ' buffet': 4,
#  ' notre-dame': 11,
#  ' sens': 2,
#  ' guinéens': 16,
#  ' z.': 3,
#  ' gaulois': 9,
#  ' hexagone': 66,
#  ' étudiante': 2,
#  ' voulez': 9,
#  ' latinos': 4,
#  ' soleil': 13,
#  'bruxelles': 61,
#  ' diciotti': 2,
#  ' helsinki': 11,
#  ' espagnol': 93,
#  ' moncloa': 2,
#  ' contrescarpe': 2,
#  ' castellón': 1,
#  ' laissons': 5,
#  ' lisbonne': 13,
#  ' notre': 25,
#  ' ceuta': 79,
#  'berlin': 59,
#  ' crisedesmigrants«la': 1,
#  ' clairefontaine': 1,
#  ' bretagne': 31,
#  ' vatican': 47,
#  'néerlandais': 5,
#  ' biennale': 11,
#  ' palerme': 4,
#  ' chiesa': 1,
#  ' di': 3,
#  ' santa': 2,
#  ' venera': 1,
#  ' pakistan': 63,
#  ' bangladesh': 35,
#  ' phéniciens': 2,
#  ' carthage': 1,
#  ' romains': 3,
#  ' panormos': 1,
#  ' saint-empire': 1,
#  ' vêpres': 1,
#  ' aragonais': 1,
#  ' autrichiens': 42,
#  ' bourbons': 1,
#  ' naples': 6,
#  ' giardino': 1,
#  ' dei': 1,
#  ' gusti': 1,
#  ' rotterdam': 2,
#  ' manifesta': 1,
#  ' 12': 2,
#  ' per': 2,
#  ' barclay': 1,
#  ' liquid': 1,
#  ' siciliens': 1,
#  ' palermitains': 1,
#  ' teatro': 1,
#  ' garibaldi': 1,
#  ' sirenetta': 1,
#  'patience': 1,
#  ' dossier': 2,
#  ' -des': 1,
#  ' landes': 1,
#  ' mondial': 2,
#  ' nijni': 1,
#  ' novgorod': 1,
#  ' seine-et-marne': 7,
#  ' seine-saint-denis': 29,
#  ' othis': 1,
#  ' inde': 35,
#  ' bel': 1,
#  ' ami': 1,
#  ' évian': 6,
#  'maltaises': 2,
#  ' maltais': 17,
#  ' moonbird': 3,
#  ' crisedesmigrantsdésormais': 1,
#  ' maltaise': 4,
#  'européens': 20,
#  ' yémen': 22,
#  ' natanz': 1,
#  ' oktoberfest': 2,
#  ' crisedesmigrantsà': 1,
#  ' rhin': 16,
#  ' spiegel': 8,
#  ' mannschaft': 7,
#  ' kaiserin': 3,
#  ' est-européens': 7,
#  ' morena': 1,
#  ' réau': 1,
#  ' menhir': 1,
#  ' diplomatie?-': 1,
#  ' en': 12,
#  ' bon': 1,
#  ' mâle': 1,
#  ' réunis': 7,
#  ' menton': 10,
#  ' cercle': 3,
#  ' réserve': 2,
#  ' histoire': 7,
#  ' abandonnons': 1,
#  'allemand': 46,
#  'cac': 3,
#  ' 40': 7,
#  ' markets': 1,
#  ' dans': 5,
#  ' valeurs': 1,
#  ' st': 5,
#  ' dupont': 6,
#  ' montpensier': 1,
#  ' pau': 6,
#  ' autre': 17,
#  ' frontières': 4,
#  ' général': 8,
#  ' vendée': 17,
#  ' aspen': 2,
#  ' tchécoslovaquie': 5,
#  ' avez': 23,
#  ' huttington': 1,
#  ' écririez': 1,
#  ' panthéon': 6,
#  ' larem': 1,
#  ' skopje': 9,
#  ' tetovo': 1,
#  ' albanaise': 12,
#  ' jeunesse': 1,
#  ' maltaises': 6,
#  ' valence': 15,
#  ' bavarois': 11,
#  ' visegrad': 81,
#  ' maersk': 3,
#  ' lifeline': 6,
#  'collège': 1,
#  ' proche': 69,
#  ' orient': 67,
#  ' mordants': 1,
#  ' collège': 4,
#  ' bernardins': 4,
#  ' meseberg': 13,
#  ' attendons': 1,
#  ' eurogroupe': 23,
#  'italie': 9,
#  ' alexander': 4,
#  ' résignée': 1,
#  ' botte': 6,
#  ' talamoni': 1,
#  ' opération': 1,
#  ' barkhane': 8,
#  ' antilles': 3,
#  ' levant': 31,
#  ' bourse': 16,
#  ' rwanda': 30,
#  ' saint-andré': 1,
#  'seize': 1,
#  ' nordique': 1,
#  ' ironie': 2,
#  ' vintimille': 26,
#  ' barcelonnette': 1,
#  'venez': 1,
#  ' île': 33,
#  ' pozzallo': 4,
#  ' tripoli': 26,
#  ' pression': 1,
#  ' jeudi': 4,
#  'allemands': 15,
#  ' burqa': 4,
#  ' bossey': 1,
#  ' genève': 39,
#  'quimper': 1,
#  ' vienne': 110,
#  ' jordanie': 86,
#  ' quimper': 1,
#  'réfugiés': 2,
#  ' tchadiens': 2,
#  ' mauritaniens': 2,
#  ' bologne': 2,
#  ' orléans': 2,
#  ' résidence': 1,
#  'états': 16,
#  ' attitude': 2,
#  ' considère': 2,
#  'françaises': 5,
#  ' gap': 4,
#  ' embrun': 1,
#  ' marée': 1,
#  ' acrobates': 1,
#  ' épilogue': 1,
#  ' corses': 2,
#  ' madeleine': 2,
#  ' toscan': 2,
#  ' croce': 1,
#  ' toscane': 3,
#  ' archipel': 5,
#  ' hawaï': 4,
#  ' kilauea': 2,
#  ' tuileries': 2,
#  ' orsay': 32,
#  ' hôtel': 32,
#  ' royal': 7,
#  ' justice': 2,
#  ' gobelins': 1,
#  ' tels': 1,
#  ' melilla': 10,
#  ' marocaine': 16,
#  ' entre': 3,
#  ' solidarité': 3,
#  ' canal': 14,
#  ' mouchamps': 2,
#  ' f.-x': 1,
#  'ive': 1,
#  ' rwandais': 4,
#  ' ramallah': 1,
#  ' somalie': 21,
#  ' capa': 1,
#  ' nachtwey': 2,
#  ' dartmouth': 2,
#  ' hampshire': 1,
#  ' oscars': 1,
#  ' hood': 1,
#  ' museum': 7,
#  ' ive': 1,
#  ' mep-fr.org': 1,
#  'luxembourg': 7,
#  ' montpellier': 8,
#  ' mont-saint-michel': 6,
#  ' évitez': 2,
#  'libyen': 1,
#  ' elysée': 53,
#  'montréal': 4,
#  ' québécois': 3,
#  ' montréal': 4,
#  ' québec': 18,
#  ' canada': 109,
#  ...}

# %%
import matplotlib.pyplot as plt


# Extraire les valeurs du dictionnaire
values = list(words.values())

# Créer un histogramme
plt.hist(values, bins=50, color='skyblue', edgecolor='black')
plt.xlim(250, 14000)
plt.ylim(0, 50)
# Ajouter un titre et des labels aux axes
plt.title('Histogramme des valeurs du dictionnaire')
plt.xlabel('Valeurs')
plt.ylabel('Fréquence')

# Afficher l'histogramme
plt.show()

# %%
print([key for key in s if words[key] > 250])
# Out:
# [' union', ' biélorussie', ' moscou', ' britanniques', ' turcs', ' mays', ' pays', ' américaine', ' afghans', ' grec', ' etat', ' hongrois', ' polonais', ' grande-bretagne', ' irak', ' afghanistan', ' américains', ' république', ' chine', ' nord', ' suède', ' libye', ' russes', ' balkans', ' italien', ' espagne', ' ukraine', ' syrien', ' britannique', ' russe', ' autriche', ' brexit', ' turc', ' américain', ' ankara', ' méditerranée', ' royaume', ' uni', ' afrique', ' allemands', ' du', ' allemand', ' française', ' schengen', ' pologne', ' hongrie', ' européens', ' calais', ' syriens', ' allemande', ' berlin', ' états-unis', ' russie', ' états', ' bruxelles', ' paris', ' syrie', ' de', ' italie', ' grèce', ' état', ' l’', ' turquie', ' français', ' -', ' allemagne', ' la', ' l', ' france', ' europe']

# %%
s = sorted(words, key=words.get)
for w in s[len(s)-50:] :
    print(w)
# Out:
#  suède
#  libye
#  russes
#  balkans
#  italien
#  espagne
#  ukraine
#  syrien
#  britannique
#  russe
#  autriche
#  brexit
#  turc
#  américain
#  ankara
#  méditerranée
#  royaume
#  uni
#  afrique
#  allemands
#  du
#  allemand
#  française
#  schengen
#  pologne
#  hongrie
#  européens
#  calais
#  syriens
#  allemande
#  berlin
#  états-unis
#  russie
#  états
#  bruxelles
#  paris
#  syrie
#  de
#  italie
#  grèce
#  état
#  l’
#  turquie
#  français
#  -
#  allemagne
#  la
#  l
#  france
#  europe

# %%
print(sorted(words.items(), key=lambda t: t[0]))
# Out:
# [('', 14), (' ', 7), ('  ', 113), ('   ', 68), ('    ', 19), ('     ', 10), ('       ', 5), ('        ', 1), (' !', 5), (' #', 2), (' &', 1), (' (', 1), (' )', 2), (' +', 3), (' -', 5262), (' -184', 1), (' -cancale', 1), (' -des', 1), (' -et', 1), (' -il', 4), (' -jérôme', 1), (' -libye', 2), (' -là', 1), (' -nord', 2), (' -pierre', 1), (' -thierry', 1), (' .', 1), (' .dans', 1), (' /', 2), (' 000personnes', 1), (' 08/03/16', 1), (' 1', 7), (' 10', 5), (' 101', 1), (' 11', 2), (' 12', 1), (' 15', 1), (' 15e', 2), (' 16', 1), (' 184personnes', 1), (' 18e', 4), (' 18h40', 1), (' 1er', 1), (' 2', 5), (' 200milliards', 1), (' 200personnes', 1), (' 2011.la', 1), (' 2012', 2), (' 2013', 1), (' 2014', 2), (' 2015', 6), (' 2015.mais', 1), (' 2015.un', 1), (' 2016', 1), (' 2017', 1), (' 2018', 1), (' 2018.le', 1), (' 215réfugiés', 1), (' 23rd', 1), (' 26', 3), (' 275euros', 1), (' 27e', 1), (' 2e', 1), (' 3-mai', 1), (' 300migrants', 1), (' 300milliards', 1), (' 350euros', 1), (' 36', 4), (' 40', 17), (' 400millions', 1), (' 45', 1), (' 470milliards', 1), (' 4l', 1), (' 5', 5), (' 500', 1), (' 500personnes', 2), (' 51', 3), (' 5e', 1), (' 6', 3), (' 68', 2), (' 7', 4), (' 8)', 1), (' 831', 1), (' 87', 1), (' 88', 2), (' :', 2), (' ?', 1), (' @esa_exomars', 1), (' a', 289), (' a.', 1), (' a.-l', 1), (' a1', 11), (' a10', 1), (' a16', 30), (' a24', 1), (' a26', 2), (' a28', 1), (' a3', 2), (' a4', 7), (' aachen', 2), (' aalen', 2), (' aarhus', 2), (' aaros', 1), (' aarsal', 1), (' abaaoud', 1), (' abaaoud-', 1), (' abakar', 1), (' abandonnez', 1), (' abandonnons', 1), (' abascal', 1), (' abaâ\\xadaoud', 1), (' abbaye', 5), (' abbaye-aux-bois', 1), (' abbeville', 2), (' abbé', 4), (' abdah', 1), (' abdalaziz', 1), (' abdelaziz', 3), (' abdelhaà¯m', 2), (' abdelkarim', 1), (' abdeslam', 8), (' abdication', 1), (' abdullah', 9), (' abe', 3), (' abeba', 27), (' abeni', 1), (' abetz', 2), (' abidjan', 14), (' abkhazie', 1), (' ablonczy', 1), (' abois', 1), (' abord»ou', 1), (' aborigènes', 1), (' abou', 47), (' aboville', 1), (' abraham', 2), (' abrantes', 1), (' absolument', 1), (' absorbée', 2), (' abuja', 2), (' abyad', 1), (' abyssins', 1), (' acat', 2), (' accenture', 1), (' accepter', 3), (' accord', 6), (' accords', 1), (' accra', 2), (' accroche', 2), (' accrochez', 1), (' accueil', 5), (' accueilli', 5), (' accueillir', 21), (' acculés', 1), (' accusé', 1), (' accès', 1), (' accéder', 1), (' aceh', 2), (' ach', 1), (' acharvieu', 1), (' achetez', 1), (' achevons', 1), (' achille', 1), (' achève', 1), (' acier', 1), (' acnam', 2), (' acquise', 1), (' acrimonie', 1), (' acrobates', 1), (' acropole', 4), (' acropolis', 1), (' actes', 11), (' action', 1), (' actionaid', 1), (' adam', 3), (' adama', 1), (' adamo', 1), (' adana', 2), (' adapter', 1), (' addis', 24), (' adel', 2), (' aden', 4), (' adenauer', 15), (' adidas', 1), (' adige', 1), (' adjointe', 1), (' adjumani', 2), (' adler-', 2), (' administrations', 1), (' administrative', 1), (' ado', 1), (' adoma', 9), (' adorno', 1), (' adour', 1), (' adra', 1), (' adresse', 2), (' adria', 1), (' adriana', 1), (' adriatique', 13), (' adrija', 1), (' adèle', 1), (' afd', 69), (' afd.', 1), (' afd.alors', 1), (' afep', 1), (' afev', 3), (' affaiblie', 11), (' affaiblis', 1), (' affaires', 14), (' affamée', 1), (' affamés', 2), (' affiches', 2), (' affirmer', 2), (' affluence', 1), (' afghan', 141), (' afghane', 47), (' afghanes', 18), (' afghanistan', 409), (' afghans', 415), (' afka', 1), (' afp.le', 1), (' afp/', 1), (' afpa', 1), (' africa', 1), (' africain', 11), (' africaine', 1), (' africains', 166), (' africanews', 1), (' afrika', 3), (' afrin', 6), (' afrine', 3), (' afrique', 1300), (' afro-américains', 5), (' afrotopia', 2), (' ag', 1), (' agadez', 25), (' agadir', 6), (' agathonissi', 2), (' agde', 1), (' age', 7), (' agence', 1), (' agency', 1), (' aggrave', 1), (' agier', 1), (' agir', 1), (' agnan', 1), (' agora', 1), (' agressions', 3), (' agriculture', 1), (' agrigente', 11) ...

# %% [markdown]
# ### Constitution du gold standard

# %%
final = pd.read_csv(r'data_cleaned/corpus_cleaned_PAMPLEMOUSSE.csv',sep=";")
final["annee"] = final.Date.apply(lambda date: date[:4])

# %%
df = final.copy()

# Calculer la distribution de chaque journal par année
distribution = df.groupby(['CJournal', 'annee']).size().reset_index(name='count')

# Calculer le nombre total d'articles par journal et année
total_articles = distribution['count'].sum()

# Déterminer combien d'articles doivent être sélectionnés de chaque journal chaque année
distribution['target_count'] = (distribution['count'] / total_articles * 300).round().astype(int)

# Initialiser une liste pour stocker les articles sélectionnés
gold_standard = []

# Sélectionner les articles
for index, row in distribution.iterrows():
    journal = row['CJournal']
    year = row['annee']
    target_count = row['target_count']
    
    # Filtrer les articles du journal et de l'année spécifiques
    filtered_df = df[(df['CJournal'] == journal) & (df['annee'] == year)]
    
    # Sélectionner aléatoirement les articles requis
    selected_articles = filtered_df.sample(n=target_count, random_state=42)
    
    # Ajouter les articles sélectionnés à la liste gold_standard
    gold_standard.append(selected_articles)

# Combiner les articles sélectionnés dans un nouveau DataFrame
gold_standard_df = pd.concat(gold_standard)

# Enregistrer le Gold Standard dans un nouveau fichier CSV si nécessaire
gold_standard_df.to_csv('data_cleaned/gold_standard.csv', index=False)

# %%
gold_standard_df.groupby(['CJournal', 'annee']).count()
# Out:
#                   Journal  Titre  Date  Auteur  Texte  extrait_debut  \
# CJournal   annee
# Croix      2015         4      4     4       4      4              4
#            2016         4      4     4       2      4              4
#            2017         2      2     2       0      2              2
#            2018         6      6     6       6      6              6
#            2019         3      3     3       3      3              3
#            2020         2      2     2       0      2              2
#            2021         2      2     2       0      2              2
#            2022         1      1     1       0      1              1
# Echos      2015        11     11    11      11     11             11
#            2016        14     14    14      14     14             14
#            2017         5      5     5       5      5              5
#            2018         6      6     6       6      6              6
#            2019         2      2     2       2      2              2
#            2020         1      1     1       0      1              1
#            2021         1      1     1       0      1              1
#            2022         1      1     1       0      1              1
# Figaro     2015        26     26    26      26     26             26
#            2016        28     28    28      26     28             28
#            2017        10     10    10       9     10             10
#            2018        16     16    16      16     16             16
#            2019         9      9     9       9      9              9
#            2020         5      5     5       2      5              5
#            2021         6      6     6       0      6              6
#            2022         2      2     2       0      2              2
# Libération 2015         5      5     5       4      5              5
#            2016         6      6     6       3      6              6
#            2017         3      3     3       2      3              3
#            2018         7      7     7       3      7              7
#            2019         4      4     4       2      4              4
#            2020         2      2     2       0      2              2
#            2021         2      2     2       0      2              2
#            2022         1      1     1       0      1              1
# Monde      2015        18     18    18       9     18             18
#            2016        23     23    23      10     23             23
#            2017        11     11    11       6     11             11
#            2018        10     10    10       5     10             10
#            2019         6      6     6       6      6              6
#            2020         3      3     3       1      3              3
#            2021         3      3     3       0      3              3
#            2022         1      1     1       0      1              1
# Parisien   2015         7      7     7       3      7              7
#            2016         5      5     5       2      5              5
#            2017         3      3     3       1      3              3
#            2018         3      3     3       2      3              3
#            2019         2      2     2       1      2              2
#            2020         1      1     1       0      1              1
#            2021         2      2     2       0      2              2
#
#                   extrait_fin  texte_processed  replaced_words
# CJournal   annee
# Croix      2015             4                4               4
#            2016             4                4               4
#            2017             2                2               2
#            2018             6                6               6
#            2019             3                3               3
#            2020             2                2               2
#            2021             2                2               2
#            2022             1                1               1
# Echos      2015            11               11              11
#            2016            14               14              14
#            2017             5                5               5
#            2018             6                6               6
#            2019             2                2               2
#            2020             1                1               1
#            2021             1                1               1
#            2022             1                1               1
# Figaro     2015            26               26              26
#            2016            28               28              28
#            2017            10               10              10
#            2018            16               16              16
#            2019             9                9               9
#            2020             5                5               5
#            2021             6                6               6
#            2022             2                2               2
# Libération 2015             5                5               5
#            2016             6                6               6
#            2017             3                3               3
#            2018             7                7               7
#            2019             4                4               4
#            2020             2                2               2
#            2021             2                2               2
#            2022             1                1               1
# Monde      2015            18               18              18
#            2016            23               23              23
#            2017            11               11              11
#            2018            10               10              10
#            2019             6                6               6
#            2020             3                3               3
#            2021             3                3               3
#            2022             1                1               1
# Parisien   2015             7                7               7
#            2016             5                5               5
#            2017             3                3               3
#            2018             3                3               3
#            2019             2                2               2
#            2020             1                1               1
#            2021             2                2               2

# %%
len(gold_standard)
# Out:
# 63

# %%
def replace(x):
    return replace_nationality_entities(x, df_pays.to_dict('records'))

data["texte_processed"] = data["Texte"].apply(replace)
data["replaced_words"] = data["Texte"].apply(lambda x: replace(x)[1])
data
# Out:
# <ipython-input-43-035997c6abfd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["texte_processed"] = data["Texte"].apply(replace)
# <ipython-input-43-035997c6abfd>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["replaced_words"] = data["Texte"].apply(lambda x: replace(x)[1])
#                       Journal  \
# 0     Le Figaro, no. 23520
# 1                 Le Monde
# 2     Le Figaro (site web)
# 3      Le Monde (site web)
# 4      Le Monde (site web)
# ..                        ...
# 95            Le Figaro.fr
# 96   Libération (site web)
# 97             Le Monde.fr
# 98            Le Figaro.fr
# 99    Le Figaro, no. 23264
#
#                                                 Titre        Date  \
# 0                  L'agenda caché de Moscou en Italie  2020-03-30
# 1   Récit   Les trois semaines qui ont chamboulé l...  2020-03-27
# 2   Élargissement de l’Union européenne à l’heure ...  2020-03-26
# 3   Coronavirus : les trois semaines qui ont chamb...  2020-03-26
# 4   Marc Lazar : « Plus l’Italie fait nation face ...  2020-03-25
# ..                                                ...         ...
# 95  Paris: une «maison des réfugiés» ouvre ses portes  2019-06-20
# 96  Edition principale  «La  crise des migrants a ...  2019-06-20
# 97   Bac 2019 histoire-géo : le corrigé de la série S  2019-06-18
# 98  Qu’est-ce que le MED 7, l’alliance des pays du...  2019-06-14
# 99  Marion Van Renterghem : « Les Britanniques nou...  2019-06-01
#
#                                                Auteur  \
# 0                                  Lasserre, Isabelle
# 1   Éric Albert, Cécile Boutelet, Jérôme Gautheret...
# 2                                   Tandonnet, Maxime
# 3   Eric Albert, Jérôme Gautheret, Cécile Boutelet...
# 4                                          Marc Lazar
# ..                                                ...
# 95                                 Le Figaro avec AFP
# 96                                 Augustine Passilly
# 97                                                nan
# 98                                     Baldi, Gabriel
# 99                                 Lasserre, Isabelle
#
#                                                 Texte  \
# 0   LES SYMBOLES comptent parfois plus que les fai...
# 1   Londres, Berlin, Rome et Bruxelles corresponda...
# 2   Fin observateur de la vie politique française ...
# 3   Jeudi 26 mars, les Vingt-Sept doivent se réuni...
# 4   Tribune. L’Italie est le pays qui enregistre à...
# ..                                                ...
# 95  Une «maison des réfugiés», financée par la Mai...
# 96  Le Haut-Commissariat de l'ONU pour les réfugié...
# 97  Après la philosophie, lundi 17 juin, les candi...
# 98  Le Med 7, qu’est-ce que c’est? Composé de sept...
# 99  La grand reporter consacre un livre, à la fois...
#
#                                         extrait_debut  \
# 0    Sur les camions militaires qui, en colonnes, ...
# 1    - Jeudi 26 mars, les Vingt-Sept devaient se r...
# 2   contributeur régulier du FigaroVox, Maxime Tan...
# 3   n visioconférence pour la troisième fois en mo...
# 4    date du 25 mars le plus grand nombre de morts...
# ..                                                ...
# 95   de Paris et centralisant initiatives et infor...
# 96  lerte sur un record de déplacements forcés. So...
# 97  s au bac 2019 ont planché sur les épreuves d'h...
# 98  ys du sud de l’Union européenne (France, Espag...
# 99  rsonnel et politique, à une Europe qu'elle a s...
#
#                                           extrait_fin    CJournal  \
# 0   Deux semaines pour se ressaisir et s'unir ou p...      Figaro
# 1   pandémie touche tout le monde, indifféremment ...       Monde
# 2   es yeux et de se préparer au changement d’un m...      Figaro
# 3   e la tenue de ses comptes publics, n’est pas s...       Monde
# 4   t de la School of Government de la Luiss (Libr...       Monde
# ..                                                ...         ...
# 95   de Paris de se marquer comme une ville refuge...      Figaro
# 96  es migrants vénézuéliens à la frontière péruvi...  Libération
# 97  aciques et ponctuels; dans la troisième des fi...       Monde
# 98  ccupation turque du nord de l’île ou encore la...      Figaro
# 99  nsonge comme stratégie politique. Résultat : c...      Figaro
#
#            crisis_term                                    texte_processed  \
# 0   migrant_migratoire  (le symbol comptent parfois plus que le fait ....
# 1   migrant_migratoire  (PAMPLEMOUSSE , PAMPLEMOUSSE , PAMPLEMOUSSE et...
# 2   migrant_migratoire  (fin observ de la vi polit français et contrib...
# 3   migrant_migratoire  (jeud 26 mar , le vingt-sept doivent se réun e...
# 4   migrant_migratoire  (tribun . l ’ PAMPLEMOUSSE est le pay qui enre...
# ..                 ...                                                ...
# 95  migrant_migratoire  (une « maison de réfugi » , financ par la mair...
# 96  migrant_migratoire  (le haut-commissariat de l'onu pour le réfugi ...
# 97  migrant_migratoire  (apres la philosoph , lund 17 juin , le candid...
# 98  migrant_migratoire  (le med 7 , qu ’ est-ce que c ’ est ? compos d...
# 99  migrant_migratoire  (la grand report consacr un livr , à la fois p...
#
#                                        replaced_words
# 0   [europ, europ, europ, europ, allemagn, europ, ...
# 1   [europ, europ, europ, europ, europ, europ, eur...
# 2   [alban, europ, europ, europ, alban, europ, all...
# 3   [europ, europ, europ, europ, europ, europ, eur...
# 4   [europ, allemagn, allemand, berlin, franc, fra...
# ..                                                ...
# 95  [paris, franc, paris, paris, franc, paris, paris]
# 96  [afghanistan, afriqu, afriqu, allemagn, keni, ...
# 97  [europ, europ, europ, europ, europ, allemagn, ...
# 98  [europ, europ, europ, europ, europ, europ, eur...
# 99  [europ, europ, europ, europ, europ, europ, eur...
#
# [100 rows x 11 columns]

# %% [markdown]
# # NLP humanitaire vs securitaire

# %%
# Données annotées
gs = pd.read_csv('./data_cleaned/gold_standard_annote.csv')
gs.head()
# Out:
#                    Journal                                              Titre  \
# 0   La Croix, no. 40303     VU D'ITALIE Matteo Renzi veut un budget « en e...
# 1   La Croix, no. 40331     Ankara, partenaire incontournable des Européen...
# 2   La Croix, no. 40327     Jeunes, réfugiés et vulnérables  L'Autriche ve...
# 3   La Croix, no. 40341                                  Éditorial   Ensemble
# 4   La Croix, no. 40529     Entretien « Réduire la distance entre les élit...
#
#          Date                   Auteur  \
# 0  2015-10-01             DANCER Marie
# 1  2015-11-03        LE TALLEC Camille
# 2  2015-10-29            VERDIER Marie
# 3  2015-11-16        GOUBERT Guillaume
# 4  2016-06-28  PLOQUIN Jean-Christophe
#
#                                                Texte  is_humanitaire  \
# 0  La saison budgétaire bat son plein en Europe. ...               0
# 1  BRUXELLES   De notre correspondante   Avec rés...               0
# 2  La longue route des migrants fluctue au gré de...               1
# 3  Depuis vendredi, la menace terroriste en Franc...               0
# 4  Qu'est-ce qui explique le malaise d'une partie...               0
#
#    is_humanitaire_check  is_securitaire  is_securitaire_check disagreement  \
# 0                     0               0                     0          NaN
# 1                     0               0                     0          NaN
# 2                     1               1                     1          NaN
# 3                     0               1                     1          NaN
# 4                     0               1                     1          NaN
#
#                                        extrait_debut  \
# 0  me la France et les autres pays de la zone eur...
# 1  e et sobriété, l'Union européenne a réagi aux ...
# 2  ermetures de frontière. À mesure que la Hongri...
# 3  complètement changé de dimension. Ce que les s...
# 4  s Européens vis-à-vis de la construction europ...
#
#                                          extrait_fin CJournal  \
# 0  ns le même temps, l'Italie réclame, comme l'Au...    Croix
# 1   moment » , estimait de son côté le chef de l'...    Croix
# 2  semigratoire est susceptible de  « provoquer u...    Croix
# 3  symbole serait que la France bénéficie de renf...    Croix
# 4  ui resterait ouverte à d'autres qui voudraient...    Croix
#
#                                      texte_processed  \
# 0  La saison budgétaire bat son plein en PAMPLEMO...
# 1  BRUXELLES    De notre correspondante    Avec r...
# 2  La longue route des migrants fluctue au gré de...
# 3  Depuis vendredi , la menace terroriste en PAMP...
# 4  Qu' est -ce qui explique le malaise d' une par...
#
#                                       replaced_words  annee
# 0  ['Europe', 'la', 'France', "l'", 'Italie', 'Br...   2015
# 1  ['Turquie', 'Bruxelles', 'Ankara', 'Turquie', ...   2015
# 2  ['Hongrie', 'Serbie', 'Croatie', 'Grèce', 'Oue...   2015
# 3  ['France', 'La', 'France', 'Sahel', 'Proche', ...   2015
# 4  ['Européens', 'Portugal', 'Espagne', 'Italie',...   2016

# %%
display(gs[["CJournal","is_humanitaire","is_securitaire"]].groupby(["is_humanitaire","is_securitaire"]).count())
       
display(gs[["CJournal","Texte","is_humanitaire","is_securitaire"]].groupby(["CJournal","is_humanitaire","is_securitaire"]).count())
# Out:
#                                CJournal
# is_humanitaire is_securitaire
# 0              0                    100
#                1                     84
# 1              0                     50
#                1                     61
#                                           Texte
# CJournal   is_humanitaire is_securitaire
# Croix      0              0                  10
#                           1                   2
#            1              0                   7
#                           1                   5
# Echos      0              0                  15
#                           1                  12
#            1              0                   4
#                           1                  10
# Figaro     0              0                  33
#                           1                  37
#            1              0                  16
#                           1                  16
# Libération 0              0                   9
#                           1                   8
#            1              0                   4
#                           1                   9
# Monde      0              0                  23
#                           1                  20
#            1              0                  13
#                           1                  19
# Parisien   0              0                  10
#                           1                   5
#            1              0                   6
#                           1                   2

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

data = gs.copy()

# Diviser les données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(data['Texte'], data[['is_humanitaire', 'is_securitaire']], test_size=0.2, random_state=42)

# Créer un vecteur de comptage pour transformer les textes en matrices de fréquence de mots
vectorizer = CountVectorizer()

# Transformer les textes d'entraînement et de test
X_train_vect = vectorizer.fit_transform(X_train)
X_test_vect = vectorizer.transform(X_test)

# Créer un classifieur bayésien pour la classification humanitaire
clf_humanitaire = MultinomialNB()
clf_humanitaire.fit(X_train_vect, y_train['is_humanitaire'])

# Créer un classifieur bayésien pour la classification sécuritaire
clf_securitaire = MultinomialNB()
clf_securitaire.fit(X_train_vect, y_train['is_securitaire'])

# Faire des prédictions sur l'ensemble de test pour chaque classifieur
y_pred_humanitaire = clf_humanitaire.predict(X_test_vect)
y_pred_securitaire = clf_securitaire.predict(X_test_vect)

# Analyser les résultats pour la classification humanitaire
print("Analyse des erreurs pour la classification humanitaire :")
print(classification_report(y_test['is_humanitaire'], y_pred_humanitaire))
print("Matrice de confusion pour humanitaire :")
print(confusion_matrix(y_test['is_humanitaire'], y_pred_humanitaire))

# Analyser les résultats pour la classification sécuritaire
print("\nAnalyse des erreurs pour la classification sécuritaire :")
print(classification_report(y_test['is_securitaire'], y_pred_securitaire))
print("Matrice de confusion pour sécuritaire :")
print(confusion_matrix(y_test['is_securitaire'], y_pred_securitaire))
# Out:
# Analyse des erreurs pour la classification humanitaire :
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81        42
#            1       0.53      0.53      0.53        17
#
#     accuracy                           0.73        59
#    macro avg       0.67      0.67      0.67        59
# weighted avg       0.73      0.73      0.73        59
#
# Matrice de confusion pour humanitaire :
# [[34  8]
#  [ 8  9]]
#
# Analyse des erreurs pour la classification sécuritaire :
#               precision    recall  f1-score   support
#
#            0       0.89      0.44      0.59        36
#            1       0.51      0.91      0.66        23
#
#     accuracy                           0.63        59
#    macro avg       0.70      0.68      0.62        59
# weighted avg       0.74      0.63      0.62        59
#
# Matrice de confusion pour sécuritaire :
# [[16 20]
#  [ 2 21]]

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

data = gs.copy()

# Diviser les données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(data['texte_processed'], data[['is_humanitaire', 'is_securitaire']], test_size=0.2, random_state=42)

# Créer un vecteur de comptage pour transformer les textes en matrices de fréquence de mots
vectorizer = CountVectorizer()

# Transformer les textes d'entraînement et de test
X_train_vect = vectorizer.fit_transform(X_train)
X_test_vect = vectorizer.transform(X_test)

# Créer un classifieur bayésien pour la classification humanitaire
clf_humanitaire = MultinomialNB()
clf_humanitaire.fit(X_train_vect, y_train['is_humanitaire'])

# Créer un classifieur bayésien pour la classification sécuritaire
clf_securitaire = MultinomialNB()
clf_securitaire.fit(X_train_vect, y_train['is_securitaire'])

# Faire des prédictions sur l'ensemble de test pour chaque classifieur
y_pred_humanitaire = clf_humanitaire.predict(X_test_vect)
y_pred_securitaire = clf_securitaire.predict(X_test_vect)

# Analyser les résultats pour la classification humanitaire
print("Analyse des erreurs pour la classification humanitaire :")
print(classification_report(y_test['is_humanitaire'], y_pred_humanitaire))
print("Matrice de confusion pour humanitaire :")
print(confusion_matrix(y_test['is_humanitaire'], y_pred_humanitaire))

# Analyser les résultats pour la classification sécuritaire
print("\nAnalyse des erreurs pour la classification sécuritaire :")
print(classification_report(y_test['is_securitaire'], y_pred_securitaire))
print("Matrice de confusion pour sécuritaire :")
print(confusion_matrix(y_test['is_securitaire'], y_pred_securitaire))
# Out:
# Analyse des erreurs pour la classification humanitaire :
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.80        42
#            1       0.53      0.59      0.56        17
#
#     accuracy                           0.73        59
#    macro avg       0.68      0.69      0.68        59
# weighted avg       0.74      0.73      0.73        59
#
# Matrice de confusion pour humanitaire :
# [[33  9]
#  [ 7 10]]
#
# Analyse des erreurs pour la classification sécuritaire :
#               precision    recall  f1-score   support
#
#            0       0.88      0.39      0.54        36
#            1       0.49      0.91      0.64        23
#
#     accuracy                           0.59        59
#    macro avg       0.68      0.65      0.59        59
# weighted avg       0.72      0.59      0.58        59
#
# Matrice de confusion pour sécuritaire :
# [[14 22]
#  [ 2 21]]

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier

# Charger les données
data = gs.copy()

# Diviser les données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(data['Texte'], data[['is_humanitaire', 'is_securitaire']], test_size=0.2, random_state=42)

# Créer un vecteur de comptage pour transformer les textes en matrices de fréquence de mots
vectorizer = CountVectorizer()

# Transformer les textes d'entraînement et de test
X_train_vect = vectorizer.fit_transform(X_train)
X_test_vect = vectorizer.transform(X_test)

# Définir une liste de classifieurs à tester
classifiers = {
    "Logistic Regression": LogisticRegression(),
    "Linear SVM": LinearSVC(),
    "Random Forest": RandomForestClassifier(random_state=42)
}

# Tester chaque classifieur pour is_humanitaire et is_securitaire
for name, clf in classifiers.items():
    print(f"\nRésultats pour le classifieur : {name}")

    # Classifieur pour is_humanitaire
    clf.fit(X_train_vect, y_train['is_humanitaire'])
    y_pred_humanitaire = clf.predict(X_test_vect)
    print("\nClassification humanitaire")
    print(classification_report(y_test['is_humanitaire'], y_pred_humanitaire))
    print("Matrice de confusion pour humanitaire :")
    print(confusion_matrix(y_test['is_humanitaire'], y_pred_humanitaire))

    # Classifieur pour is_securitaire
    clf.fit(X_train_vect, y_train['is_securitaire'])
    y_pred_securitaire = clf.predict(X_test_vect)
    print("\nClassification sécuritaire")
    print(classification_report(y_test['is_securitaire'], y_pred_securitaire))
    print("Matrice de confusion pour sécuritaire :")
    print(confusion_matrix(y_test['is_securitaire'], y_pred_securitaire))
# Out:
# Résultats pour le classifieur : Logistic Regression
# C:\Users\tlp\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Classification humanitaire
#               precision    recall  f1-score   support
#
#            0       0.76      0.83      0.80        42
#            1       0.46      0.35      0.40        17
#
#     accuracy                           0.69        59
#    macro avg       0.61      0.59      0.60        59
# weighted avg       0.67      0.69      0.68        59
#
# Matrice de confusion pour humanitaire :
# [[35  7]
#  [11  6]]
# C:\Users\tlp\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\tlp\Anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\tlp\Anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Classification sécuritaire
#               precision    recall  f1-score   support
#
#            0       0.76      0.72      0.74        36
#            1       0.60      0.65      0.63        23
#
#     accuracy                           0.69        59
#    macro avg       0.68      0.69      0.68        59
# weighted avg       0.70      0.69      0.70        59
#
# Matrice de confusion pour sécuritaire :
# [[26 10]
#  [ 8 15]]
#
# Résultats pour le classifieur : Linear SVM
#
# Classification humanitaire
#               precision    recall  f1-score   support
#
#            0       0.77      0.81      0.79        42
#            1       0.47      0.41      0.44        17
#
#     accuracy                           0.69        59
#    macro avg       0.62      0.61      0.61        59
# weighted avg       0.68      0.69      0.69        59
#
# Matrice de confusion pour humanitaire :
# [[34  8]
#  [10  7]]
#
# Classification sécuritaire
#               precision    recall  f1-score   support
#
#            0       0.78      0.69      0.74        36
#            1       0.59      0.70      0.64        23
#
#     accuracy                           0.69        59
#    macro avg       0.69      0.70      0.69        59
# weighted avg       0.71      0.69      0.70        59
#
# Matrice de confusion pour sécuritaire :
# [[25 11]
#  [ 7 16]]
#
# Résultats pour le classifieur : Random Forest
#
# Classification humanitaire
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88        42
#            1       1.00      0.35      0.52        17
#
#     accuracy                           0.81        59
#    macro avg       0.90      0.68      0.70        59
# weighted avg       0.85      0.81      0.78        59
#
# Matrice de confusion pour humanitaire :
# [[42  0]
#  [11  6]]
#
# Classification sécuritaire
#               precision    recall  f1-score   support
#
#            0       0.75      0.67      0.71        36
#            1       0.56      0.65      0.60        23
#
#     accuracy                           0.66        59
#    macro avg       0.65      0.66      0.65        59
# weighted avg       0.67      0.66      0.66        59
#
# Matrice de confusion pour sécuritaire :
# [[24 12]
#  [ 8 15]]

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier

# Charger les données
data = gs.copy()

# Diviser les données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(data['texte_processed'], data[['is_humanitaire', 'is_securitaire']], test_size=0.2, random_state=42)

# Créer un vecteur de comptage pour transformer les textes en matrices de fréquence de mots
vectorizer = CountVectorizer()

# Transformer les textes d'entraînement et de test
X_train_vect = vectorizer.fit_transform(X_train)
X_test_vect = vectorizer.transform(X_test)

# Définir une liste de classifieurs à tester
classifiers = {
    "Logistic Regression": LogisticRegression(),
    "Linear SVM": LinearSVC(),
    "Random Forest": RandomForestClassifier(random_state=42)
}

# Tester chaque classifieur pour is_humanitaire et is_securitaire
for name, clf in classifiers.items():
    print(f"\nRésultats pour le classifieur : {name}")

    # Classifieur pour is_humanitaire
    clf.fit(X_train_vect, y_train['is_humanitaire'])
    y_pred_humanitaire = clf.predict(X_test_vect)
    print("\nClassification humanitaire")
    print(classification_report(y_test['is_humanitaire'], y_pred_humanitaire))
    print("Matrice de confusion pour humanitaire :")
    print(confusion_matrix(y_test['is_humanitaire'], y_pred_humanitaire))

    # Classifieur pour is_securitaire
    clf.fit(X_train_vect, y_train['is_securitaire'])
    y_pred_securitaire = clf.predict(X_test_vect)
    print("\nClassification sécuritaire")
    print(classification_report(y_test['is_securitaire'], y_pred_securitaire))
    print("Matrice de confusion pour sécuritaire :")
    print(confusion_matrix(y_test['is_securitaire'], y_pred_securitaire))
# Out:
# Résultats pour le classifieur : Logistic Regression
# C:\Users\tlp\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Classification humanitaire
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81        42
#            1       0.53      0.53      0.53        17
#
#     accuracy                           0.73        59
#    macro avg       0.67      0.67      0.67        59
# weighted avg       0.73      0.73      0.73        59
#
# Matrice de confusion pour humanitaire :
# [[34  8]
#  [ 8  9]]
# C:\Users\tlp\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\tlp\Anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Classification sécuritaire
#               precision    recall  f1-score   support
#
#            0       0.73      0.75      0.74        36
#            1       0.59      0.57      0.58        23
#
#     accuracy                           0.68        59
#    macro avg       0.66      0.66      0.66        59
# weighted avg       0.68      0.68      0.68        59
#
# Matrice de confusion pour sécuritaire :
# [[27  9]
#  [10 13]]
#
# Résultats pour le classifieur : Linear SVM
#
# Classification humanitaire
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.81        42
#            1       0.53      0.47      0.50        17
#
#     accuracy                           0.73        59
#    macro avg       0.66      0.65      0.66        59
# weighted avg       0.72      0.73      0.72        59
#
# Matrice de confusion pour humanitaire :
# [[35  7]
#  [ 9  8]]
#
# Classification sécuritaire
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        36
#            1       0.61      0.61      0.61        23
#
#     accuracy                           0.69        59
#    macro avg       0.68      0.68      0.68        59
# weighted avg       0.69      0.69      0.69        59
#
# Matrice de confusion pour sécuritaire :
# [[27  9]
#  [ 9 14]]
#
# Résultats pour le classifieur : Random Forest
# C:\Users\tlp\Anaconda3\lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Classification humanitaire
#               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88        42
#            1       1.00      0.29      0.45        17
#
#     accuracy                           0.80        59
#    macro avg       0.89      0.65      0.66        59
# weighted avg       0.84      0.80      0.75        59
#
# Matrice de confusion pour humanitaire :
# [[42  0]
#  [12  5]]
#
# Classification sécuritaire
#               precision    recall  f1-score   support
#
#            0       0.74      0.69      0.71        36
#            1       0.56      0.61      0.58        23
#
#     accuracy                           0.66        59
#    macro avg       0.65      0.65      0.65        59
# weighted avg       0.67      0.66      0.66        59
#
# Matrice de confusion pour sécuritaire :
# [[25 11]
#  [ 9 14]]

# %%
df_cleaned = pd.read_csv('./data_cleaned/corpus_cleaned_PAMPLEMOUSSE.csv',sep=";")
df_cleaned.head()
# Out:
#                     Journal  \
# 0   Le Figaro, no. 23520
# 1   Le Figaro (site web)
# 2   Le Figaro (site web)
# 3   Le Figaro, no. 23505
# 4   Le Figaro (site web)
#
#                                                Titre        Date  \
# 0                 L'agenda caché de Moscou en Italie  2020-03-30
# 1  Élargissement de l’Union européenne à l’heure ...  2020-03-26
# 2  Coronavirus, un révélateur des faiblesses de l...  2020-03-12
# 3                                            EN BREF  2020-03-12
# 4  Coralie Delaume: «Un choc externe pourrait pro...  2020-03-11
#
#                           Auteur  \
# 0             Lasserre, Isabelle
# 1              Tandonnet, Maxime
# 2  Long, Didier, Laye, Sébastien
# 3                Portes, Thierry
# 4                  Imad, Joachim
#
#                                                Texte  \
# 0  LES SYMBOLES comptent parfois plus que les fai...
# 1  Fin observateur de la vie politique française ...
# 2  Didier Long est physicien. Sébastien Laye est ...
# 3  Collision entre un navire grec et un patrouill...
# 4  Coralie Delaume est essayiste. Elle a notammen...
#
#                                        extrait_debut  \
# 0   Sur les camions militaires qui, en colonnes, ...
# 1  contributeur régulier du FigaroVox, Maxime Tan...
# 2  repreneur dans l’immobilier, chercheur associé...
# 3   turc Les garde-côtes grecs ont déclaré qu'un ...
# 4  crit Le Couple franco-allemand n’existe pas (M...
#
#                                          extrait_fin CJournal  \
# 0  Deux semaines pour se ressaisir et s'unir ou p...   Figaro
# 1  es yeux et de se préparer au changement d’un m...   Figaro
# 2  faire un choix clair: l’idéologie rigoriste as...   Figaro
# 3  en Afghanistan, ouvrant la voie à des pourparl...   Figaro
# 4  on approche du la fin. De celle de l’Union eur...   Figaro
#
#                                      texte_processed  \
# 0  LES SYMBOLES comptent parfois plus que les fai...
# 1  Fin observateur de la vie politique PAMPLEMOUS...
# 2  Didier Long est physicien . Sébastien Laye est...
# 3  Collision entre un navire PAMPLEMOUSSE et un p...
# 4  Coralie Delaume est essayiste . Elle a notamme...
#
#                                       replaced_words
# 0  ['Rome', 'Bergame', 'russe', 'italien', 'De', ...
# 1  ['française', 'États', 'l’', 'Macédoine', 'du'...
# 2  ['l’', 'Chine', 'l’', 'région', 'de', 'Wuhan',...
# 3  ['grec', 'turc', 'grecs', 'turc', 'turc', "l'"...
# 4  ['FIGAROVOX.-', 'italien', 'l’', 'Quelles', 'l...

# %%
clf_humanitaire = RandomForestClassifier(random_state=42)
clf_securitaire = RandomForestClassifier(random_state=42)

# Données d'entraiment issues du GS
X_train, X_test, y_train, y_test = train_test_split(data['texte_processed'], data[['is_humanitaire', 'is_securitaire']], test_size=0.2, random_state=42)

# Créer un vecteur de comptage pour transformer les textes en matrices de fréquence de mots
vectorizer = CountVectorizer()

# Transformer les textes d'entraînement et de test
X_train_vect = vectorizer.fit_transform(X_train)
X_test_vect = vectorizer.transform(X_test)

# Entraintement
clf_humanitaire.fit(X_train_vect, y_train['is_humanitaire'])
clf_securitaire.fit(X_train_vect, y_train['is_securitaire'])

# Application
print("Prediction is_humanitaire")
df_cleaned["is_humanitaire_pred"] = clf_humanitaire.predict(vectorizer.transform(df_cleaned["texte_processed"]))
print("Prediction is_securitaire")
df_cleaned["is_securitaire_pred"] = clf_securitaire.predict(vectorizer.transform(df_cleaned["texte_processed"]))
print("Done")
# Out:
# Prediction is_humanitaire
# Prediction is_securitaire
# Done

# %%
display(df_cleaned[["CJournal","is_humanitaire_pred","is_securitaire_pred"]].groupby(["is_humanitaire_pred","is_securitaire_pred"]).count())
       
display(df_cleaned[["CJournal","Texte","is_humanitaire_pred","is_securitaire_pred"]].groupby(["CJournal","is_humanitaire_pred","is_securitaire_pred"]).count())
# Out:
#                                          CJournal
# is_humanitaire_pred is_securitaire_pred
# 0                   0                        4374
#                     1                        2920
# 1                   0                         248
#                     1                        1376
#                                                     Texte
# CJournal   is_humanitaire_pred is_securitaire_pred
# Croix      0                   0                      393
#                                1                      200
#            1                   0                       38
#                                1                      166
# Echos      0                   0                      738
#                                1                      369
#            1                   0                       30
#                                1                      127
# Figaro     0                   0                     1658
#                                1                      949
#            1                   0                       67
#                                1                      356
# Libération 0                   0                      374
#                                1                      287
#            1                   0                       25
#                                1                      220
# Monde      0                   0                      779
#                                1                      984
#            1                   0                       50
#                                1                      419
# Parisien   0                   0                      432
#                                1                      131
#            1                   0                       38
#                                1                       88

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Analyser la proportion d'articles de chaque type
print("Proportion d'articles classés comme humanitaires et sécuritaires :")
prop_humanitaire = df_cleaned['is_humanitaire_pred'].mean()
prop_securitaire = df_cleaned['is_securitaire_pred'].mean()
print(f"Humanitaires : {prop_humanitaire * 100:.2f}%")
print(f"Sécuritaires : {prop_securitaire * 100:.2f}%")

# Segmentation par journaux
print("\nAnalyse par journaux :")
grouped_by_journal = df_cleaned.groupby('CJournal')
journal_analysis = grouped_by_journal.agg({
    'is_humanitaire_pred': 'mean',
    'is_securitaire_pred': 'mean'
})
print(journal_analysis)

# Segmentation par années
print("\nAnalyse par années :")
df_cleaned["Année"] = df_cleaned["Date"].apply(lambda x: x[:4])
grouped_by_year = df_cleaned.groupby('Année')
year_analysis = grouped_by_year.agg({
    'is_humanitaire_pred': 'mean',
    'is_securitaire_pred': 'mean'
})
print(year_analysis)

# Visualisation des proportions d'articles classés humanitaires et sécuritaires
plt.figure(figsize=(12, 6))

# Graphique à barres pour les journaux
plt.subplot(1, 2, 1)
sns.barplot(x=journal_analysis.index, y='is_humanitaire_pred', data=journal_analysis, color='skyblue')
sns.barplot(x=journal_analysis.index, y='is_securitaire_pred', data=journal_analysis, color='salmon')
plt.title("Proportions par journaux")
plt.xlabel("Journal")
plt.ylabel("Proportion")
plt.legend(["Humanitaire", "Sécuritaire"])

# Graphique à lignes pour les années
plt.subplot(1, 2, 2)
sns.lineplot(x=year_analysis.index, y='is_humanitaire_pred', data=year_analysis, label='Humanitaire', marker='o')
sns.lineplot(x=year_analysis.index, y='is_securitaire_pred', data=year_analysis, label='Sécuritaire', marker='o')
plt.title("Proportions par années")
plt.xlabel("Année")
plt.ylabel("Proportion")
plt.legend()

# Afficher les graphiques
plt.tight_layout()
plt.show()
# Out:
# Proportion d'articles classés comme humanitaires et sécuritaires :
# Humanitaires : 18.21%
# Sécuritaires : 48.17%
#
# Analyse par journaux :
#             is_humanitaire_pred  is_securitaire_pred
# CJournal
# Croix                  0.255960             0.459222
# Echos                  0.124209             0.392405
# Figaro                 0.139604             0.430693
# Libération             0.270419             0.559603
# Monde                  0.210125             0.628584
# Parisien               0.182874             0.317852
#
# Analyse par années :
#        is_humanitaire_pred  is_securitaire_pred
# Année
# 2009              0.333333             0.333333
# 2010              0.500000             0.500000
# 2011              0.250000             0.375000
# 2012              0.000000             1.000000
# 2013              0.200000             0.600000
# 2014              0.461538             0.769231
# 2015              0.180536             0.441937
# 2016              0.144891             0.449749
# 2017              0.132580             0.448099
# 2018              0.163043             0.481658
# 2019              0.183168             0.522277
# 2020              0.344037             0.649083
# 2021              0.314815             0.609053
# 2022              0.321429             0.596939

# %%
# Calcul des catégories
df_cleaned['category'] = (
    df_cleaned['is_humanitaire_pred'].astype(str) + '_' + df_cleaned['is_securitaire_pred'].astype(str)
)
# Convertir les catégories en descriptifs
df_cleaned['category'] = df_cleaned['category'].replace({
    '1_0': 'Humanitaire seulement',
    '0_1': 'Sécuritaire seulement',
    '1_1': 'Humanitaire et sécuritaire',
    '0_0': 'Aucun des deux'
})

# Segmentation par journaux
grouped_by_journal = df_cleaned.groupby(['CJournal', 'category']).size().unstack().fillna(0)

# Calcul des proportions pour chaque journal
proportions_by_journal = grouped_by_journal.div(grouped_by_journal.sum(axis=1), axis=0) * 100

# Créer un graphique à barres empilées à 100% pour les journaux
proportions_by_journal.plot(kind='barh', stacked=True, figsize=(12, 6), colormap='viridis')
plt.title("Proportions d'articles classés par type et par journal")
plt.xlabel("Journal")
plt.ylabel("Proportion (%)")
plt.legend(title="Catégorie")
plt.show()

# Segmentation par années
grouped_by_year = df_cleaned.groupby(['Année', 'category']).size().unstack().fillna(0)

# Calcul des proportions pour chaque année
proportions_by_year = grouped_by_year.div(grouped_by_year.sum(axis=1), axis=0) * 100

# Créer un graphique à barres empilées à 100% pour les années
proportions_by_year.plot(kind='barh', stacked=True, figsize=(12, 6), colormap='viridis')
plt.title("Proportions d'articles classés par type et par année")
plt.xlabel("Année")
plt.ylabel("Proportion (%)")
plt.legend(title="Catégorie")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_cleaned['replaced_words'] = df_cleaned.replaced_words.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
# Définir une liste de mots à ne pas renvoyer
exclude_words = ["word1", "word2", "word3"]  # Remplacez par les mots à exclure

# Fonction pour analyser les mots les plus présents dans chaque catégorie
def analyze_words(df, groupby_cols, title_suffix=''):
    # Calcul des statistiques pour chaque mot
    word_analysis = df.explode('replaced_words')  # Éclater la liste replaced_words en lignes individuelles
    word_analysis = word_analysis[~word_analysis['replaced_words'].isin(exclude_words)]  # Exclure les mots à ne pas renvoyer

    # Calculer le nombre d'articles contenant chaque mot par catégorie
    word_count_by_category = word_analysis.groupby(groupby_cols + ['replaced_words']).size().reset_index(name='word_count')
    
    # Calculer le nombre total d'articles par catégorie
    total_articles_by_category = df.groupby(groupby_cols).size().reset_index(name='total_count')
    
    # Fusionner les données pour calculer la proportion d'articles contenant chaque mot
    word_proportion_by_category = word_count_by_category.merge(total_articles_by_category, on=groupby_cols)
    word_proportion_by_category['proportion'] = word_proportion_by_category['word_count'] / word_proportion_by_category['total_count']
    
    # Trier les mots par proportion décroissante et affichage des résultats
    word_proportion_by_category = word_proportion_by_category.sort_values(by=['proportion'], ascending=False)
    
    print(f"Top mots par proportion pour chaque catégorie {title_suffix}:")
    print(word_proportion_by_category.head(10))
    
    # Visualisation des résultats
    plt.figure(figsize=(12, 8))
    sns.barplot(x='proportion', y='replaced_words', hue='category', data=word_proportion_by_category.head(10), palette='viridis')
    plt.title(f"Top mots par proportion pour chaque catégorie {title_suffix}")
    plt.show()
    
analyze_words(df_cleaned, ['CJournal', 'category'], title_suffix='')
# Out:
# Top mots par proportion pour chaque catégorie :
#          CJournal                    category replaced_words  word_count  \
# 15683      Figaro       Sécuritaire seulement         Europe        2969
# 6291        Echos  Humanitaire et sécuritaire         Europe         377
# 30235       Monde       Sécuritaire seulement         Europe        2917
# 34730    Parisien  Humanitaire et sécuritaire         Europe         250
# 7540        Echos       Sécuritaire seulement         Europe        1040
# 26880       Monde  Humanitaire et sécuritaire         Europe        1109
# 12571      Figaro  Humanitaire et sécuritaire         Europe         939
# 22424  Libération       Sécuritaire seulement         Europe         738
# 3405        Croix       Sécuritaire seulement         Europe         490
# 34803    Parisien  Humanitaire et sécuritaire        Hongrie         197
#
#        total_count  proportion
# 15683          949    3.128556
# 6291           127    2.968504
# 30235          984    2.964431
# 34730           88    2.840909
# 7540           369    2.818428
# 26880          419    2.646778
# 12571          356    2.637640
# 22424          287    2.571429
# 3405           200    2.450000
# 34803           88    2.238636

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_cleaned['replaced_words'] = df_cleaned.replaced_words.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
# Définir une liste de mots à ne pas renvoyer
exclude_words = ["word1", "word2", "word3"]  # Remplacez par les mots à exclure

# Fonction pour analyser les mots les plus présents dans chaque catégorie
def analyze_words(df, groupby_cols, title_suffix=''):
    # Calcul des statistiques pour chaque mot
    word_analysis = df.explode('replaced_words')  # Éclater la liste replaced_words en lignes individuelles
    word_analysis = word_analysis[~word_analysis['replaced_words'].isin(exclude_words)]  # Exclure les mots à ne pas renvoyer

    # Calculer le nombre d'articles contenant chaque mot par catégorie
    word_count_by_category = word_analysis.groupby(groupby_cols + ['replaced_words']).size().reset_index(name='word_count')
    
    # Calculer le nombre total d'articles par catégorie
    total_articles_by_category = df.groupby(groupby_cols).size().reset_index(name='total_count')
    
    # Fusionner les données pour calculer la proportion d'articles contenant chaque mot
    word_proportion_by_category = word_count_by_category.merge(total_articles_by_category, on=groupby_cols)
    word_proportion_by_category['proportion'] = word_proportion_by_category['word_count'] / word_proportion_by_category['total_count']
    
    # Trier les mots par proportion décroissante et affichage des résultats
    word_proportion_by_category = word_proportion_by_category.sort_values(by=['proportion'], ascending=False)
    
    print(f"Top mots par proportion pour chaque catégorie {title_suffix}:")
    print(word_proportion_by_category.head(10))
    
    # Visualisation des résultats
    plt.figure(figsize=(12, 8))
    sns.barplot(x='proportion', y='replaced_words', hue='category', data=word_proportion_by_category.head(10), palette='viridis')
    plt.title(f"Top mots par proportion pour chaque catégorie {title_suffix}")
    plt.show()
    
analyze_words(df_cleaned, ['CJournal', 'category'], title_suffix='')
# Out:
#                        Journal  \
# 0      Le Figaro, no. 23520
# 0      Le Figaro, no. 23520
# 0      Le Figaro, no. 23520
# 0      Le Figaro, no. 23520
# 0      Le Figaro, no. 23520
# ...                        ...
# 8917                 Les Echos
# 8917                 Les Echos
# 8917                 Les Echos
# 8917                 Les Echos
# 8917                 Les Echos
#
#                                                   Titre        Date  \
# 0                    L'agenda caché de Moscou en Italie  2020-03-30
# 0                    L'agenda caché de Moscou en Italie  2020-03-30
# 0                    L'agenda caché de Moscou en Italie  2020-03-30
# 0                    L'agenda caché de Moscou en Italie  2020-03-30
# 0                    L'agenda caché de Moscou en Italie  2020-03-30
# ...                                                 ...         ...
# 8917  Crise  migratoire aux Canaries : l'Europe doit...  2020-05-27
# 8917  Crise  migratoire aux Canaries : l'Europe doit...  2020-05-27
# 8917  Crise  migratoire aux Canaries : l'Europe doit...  2020-05-27
# 8917  Crise  migratoire aux Canaries : l'Europe doit...  2020-05-27
# 8917  Crise  migratoire aux Canaries : l'Europe doit...  2020-05-27
#
#                   Auteur                                              Texte  \
# 0     Lasserre, Isabelle  LES SYMBOLES comptent parfois plus que les fai...
# 0     Lasserre, Isabelle  LES SYMBOLES comptent parfois plus que les fai...
# 0     Lasserre, Isabelle  LES SYMBOLES comptent parfois plus que les fai...
# 0     Lasserre, Isabelle  LES SYMBOLES comptent parfois plus que les fai...
# 0     Lasserre, Isabelle  LES SYMBOLES comptent parfois plus que les fai...
# ...                  ...                                                ...
# 8917                 NaN  La déception a été à la hauteur de l'espoir, i...
# 8917                 NaN  La déception a été à la hauteur de l'espoir, i...
# 8917                 NaN  La déception a été à la hauteur de l'espoir, i...
# 8917                 NaN  La déception a été à la hauteur de l'espoir, i...
# 8917                 NaN  La déception a été à la hauteur de l'espoir, i...
#
#                                           extrait_debut  \
# 0      Sur les camions militaires qui, en colonnes, ...
# 0      Sur les camions militaires qui, en colonnes, ...
# 0      Sur les camions militaires qui, en colonnes, ...
# 0      Sur les camions militaires qui, en colonnes, ...
# 0      Sur les camions militaires qui, en colonnes, ...
# ...                                                 ...
# 8917  nse, il y a dix ans. Le 17 december2010, le su...
# 8917  nse, il y a dix ans. Le 17 december2010, le su...
# 8917  nse, il y a dix ans. Le 17 december2010, le su...
# 8917  nse, il y a dix ans. Le 17 december2010, le su...
# 8917  nse, il y a dix ans. Le 17 december2010, le su...
#
#                                             extrait_fin CJournal  \
# 0     Deux semaines pour se ressaisir et s'unir ou p...   Figaro
# 0     Deux semaines pour se ressaisir et s'unir ou p...   Figaro
# 0     Deux semaines pour se ressaisir et s'unir ou p...   Figaro
# 0     Deux semaines pour se ressaisir et s'unir ou p...   Figaro
# 0     Deux semaines pour se ressaisir et s'unir ou p...   Figaro
# ...                                                 ...      ...
# 8917  e n'ait été qu'une illustration de cette ligne...    Echos
# 8917  e n'ait été qu'une illustration de cette ligne...    Echos
# 8917  e n'ait été qu'une illustration de cette ligne...    Echos
# 8917  e n'ait été qu'une illustration de cette ligne...    Echos
# 8917  e n'ait été qu'une illustration de cette ligne...    Echos
#
#                                         texte_processed replaced_words  \
# 0     LES SYMBOLES comptent parfois plus que les fai...           Rome
# 0     LES SYMBOLES comptent parfois plus que les fai...        Bergame
# 0     LES SYMBOLES comptent parfois plus que les fai...          russe
# 0     LES SYMBOLES comptent parfois plus que les fai...        italien
# 0     LES SYMBOLES comptent parfois plus que les fai...             De
# ...                                                 ...            ...
# 8917  La déception a été à la hauteur de l' espoir ,...       Regardez
# 8917  La déception a été à la hauteur de l' espoir ,...        Algérie
# 8917  La déception a été à la hauteur de l' espoir ,...          Liban
# 8917  La déception a été à la hauteur de l' espoir ,...           Irak
# 8917  La déception a été à la hauteur de l' espoir ,...         Soudan
#
#       is_humanitaire_pred  is_securitaire_pred Année               category  \
# 0                       0                    0  2020         Aucun des deux
# 0                       0                    0  2020         Aucun des deux
# 0                       0                    0  2020         Aucun des deux
# 0                       0                    0  2020         Aucun des deux
# 0                       0                    0  2020         Aucun des deux
# ...                   ...                  ...   ...                    ...
# 8917                    0                    1  2020  Sécuritaire seulement
# 8917                    0                    1  2020  Sécuritaire seulement
# 8917                    0                    1  2020  Sécuritaire seulement
# 8917                    0                    1  2020  Sécuritaire seulement
# 8917                    0                    1  2020  Sécuritaire seulement
#
#                                           replace_words
# 0     [Rome, Bergame, russe, italien, De, Russie, Ch...
# 0     [Rome, Bergame, russe, italien, De, Russie, Ch...
# 0     [Rome, Bergame, russe, italien, De, Russie, Ch...
# 0     [Rome, Bergame, russe, italien, De, Russie, Ch...
# 0     [Rome, Bergame, russe, italien, De, Russie, Ch...
# ...                                                 ...
# 8917  [Tunis, Afrique, du, Nord, Moyen-Orient, Pouss...
# 8917  [Tunis, Afrique, du, Nord, Moyen-Orient, Pouss...
# 8917  [Tunis, Afrique, du, Nord, Moyen-Orient, Pouss...
# 8917  [Tunis, Afrique, du, Nord, Moyen-Orient, Pouss...
# 8917  [Tunis, Afrique, du, Nord, Moyen-Orient, Pouss...
#
# [297374 rows x 15 columns]

# %%
# On teste toutes les nationalités possibles et leurs extansions
word_to_eliminate = ["l'","la","de","-","l'","l'","l’","la","le"]
L = []
for replaced_words in tqdm(df_cleaned.replaced_words) :
    l = []
    for word in replaced_words :
        word = word.lower()
        if word in df_nationalites["Masculin Singulier"].unique() :
            word = df_nationalites.loc[df_nationalites["Masculin Singulier"]==word,"Nationalité"].iloc[0]
        elif word in df_nationalites["Masculin Pluriel"].unique() :
            word = df_nationalites.loc[df_nationalites["Masculin Pluriel"]==word,"Nationalité"].iloc[0]
        elif word in df_nationalites["Féminin Singulier"].unique() :
            word = df_nationalites.loc[df_nationalites["Féminin Singulier"]==word,"Nationalité"].iloc[0]
        elif word in df_nationalites["Féminin Pluriel"].unique() :
            word = df_nationalites.loc[df_nationalites["Féminin Pluriel"]==word,"Nationalité"].iloc[0]
        else :
            if word in df_pays["Capitale"].unique() :
                word = df_pays.loc[df_pays["Capitale"]==word,"Nationalité"].iloc[0]
            if word in df_pays["Pays"].unique() :
                word = df_pays.loc[df_pays["Pays"]==word,"Nationalité"].iloc[0]
                
#         for _, row in df_nationalites.iterrows():
#             # Vérifier si le string est dans les colonnes A, B, ou C de la ligne
#             if word in (row["Masculin Singulier"], row['Masculin Pluriel'], row['Féminin Singulier'],row['Féminin Pluriel']):
#                 # Si trouvé, renvoyer la valeur de la colonne D
#                 word = row['Nationalité']
#                 continue
#             else :
#                 # On teste les pays et capital
#                 for _, row in df_pays.iterrows():
#                     # Vérifier si le string est dans les colonnes A, B, ou C de la ligne
#                     if word in (row["Pays"], row['Capitale']):
#                         # Si trouvé, renvoyer la valeur de la colonne D
#                         word = row['Nationalité']
#                         continue
        l.append(word)
    
    L.append(l)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 8918/8918 [06:11<00:00, 23.99it/s]

# %%
df_cleaned["replaced_words_cleaned"] = pd.Series(L)
df_cleaned
# Out:
#                        Journal  \
# 0      Le Figaro, no. 23520
# 1      Le Figaro (site web)
# 2      Le Figaro (site web)
# 3      Le Figaro, no. 23505
# 4      Le Figaro (site web)
# ...                        ...
# 8913                 Les Echos
# 8914                 Les Echos
# 8915                 Les Echos
# 8916                 Les Echos
# 8917                 Les Echos
#
#                                                   Titre        Date  \
# 0                    L'agenda caché de Moscou en Italie  2020-03-30
# 1     Élargissement de l’Union européenne à l’heure ...  2020-03-26
# 2     Coronavirus, un révélateur des faiblesses de l...  2020-03-12
# 3                                               EN BREF  2020-03-12
# 4     Coralie Delaume: «Un choc externe pourrait pro...  2020-03-11
# ...                                                 ...         ...
# 8913  Joe Biden met en scène sa présidence appliquée...  2021-07-22
# 8914  Aux Canaries, le drame de l'immigration a déso...  2021-05-29
# 8915     Un nouvel élan pour l'intégration européenne ?  2020-08-30
# 8916                             2020, l'année furieuse  2020-08-14
# 8917  Crise  migratoire aux Canaries : l'Europe doit...  2020-05-27
#
#                              Auteur  \
# 0                Lasserre, Isabelle
# 1                 Tandonnet, Maxime
# 2     Long, Didier, Laye, Sébastien
# 3                   Portes, Thierry
# 4                     Imad, Joachim
# ...                             ...
# 8913                            NaN
# 8914                            NaN
# 8915                            NaN
# 8916                            NaN
# 8917                            NaN
#
#                                                   Texte  \
# 0     LES SYMBOLES comptent parfois plus que les fai...
# 1     Fin observateur de la vie politique française ...
# 2     Didier Long est physicien. Sébastien Laye est ...
# 3     Collision entre un navire grec et un patrouill...
# 4     Coralie Delaume est essayiste. Elle a notammen...
# ...                                                 ...
# 8913  scandinavie - :  La Suède a présenté jeudi un ...
# 8914  De tous les dossiers posés sur la table des né...
# 8915  Cela aurait pu être l'étincelle dans le baril ...
# 8916  C'est un plongeon généralisé. Tous les indicat...
# 8917  La déception a été à la hauteur de l'espoir, i...
#
#                                           extrait_debut  \
# 0      Sur les camions militaires qui, en colonnes, ...
# 1     contributeur régulier du FigaroVox, Maxime Tan...
# 2     repreneur dans l’immobilier, chercheur associé...
# 3      turc Les garde-côtes grecs ont déclaré qu'un ...
# 4     crit Le Couple franco-allemand n’existe pas (M...
# ...                                                 ...
# 8913  jet de loi pérennisant le durcissement de ses ...
# 8914  iations entre Bruxelles et Ankara, c'est peut-...
# 8915  poudre. Pour les Européens, le Brexit avait to...
# 8916  s de flux d'entrée et de séjour sur le territo...
# 8917  nse, il y a dix ans. Le 17 december2010, le su...
#
#                                             extrait_fin CJournal  \
# 0     Deux semaines pour se ressaisir et s'unir ou p...   Figaro
# 1     es yeux et de se préparer au changement d’un m...   Figaro
# 2     faire un choix clair: l’idéologie rigoriste as...   Figaro
# 3     en Afghanistan, ouvrant la voie à des pourparl...   Figaro
# 4     on approche du la fin. De celle de l’Union eur...   Figaro
# ...                                                 ...      ...
# 8913   seront convertibles en droits de résidence pe...    Echos
# 8914   Européens partagent véritablement une volonté...    Echos
# 8915  en, malgré son manque de maniabilité,reste l'e...    Echos
# 8916  mie a également influé sur les sorties du terr...    Echos
# 8917  e n'ait été qu'une illustration de cette ligne...    Echos
#
#                                         texte_processed  \
# 0     LES SYMBOLES comptent parfois plus que les fai...
# 1     Fin observateur de la vie politique PAMPLEMOUS...
# 2     Didier Long est physicien . Sébastien Laye est...
# 3     Collision entre un navire PAMPLEMOUSSE et un p...
# 4     Coralie Delaume est essayiste . Elle a notamme...
# ...                                                 ...
# 8913  scandinavie - :   La PAMPLEMOUSSE a présenté j...
# 8914  De tous les dossiers posés sur la table des né...
# 8915  Cela aurait pu être l' étincelle dans le baril...
# 8916  C' est un plongeon généralisé . Tous les indic...
# 8917  La déception a été à la hauteur de l' espoir ,...
#
#                                          replaced_words  is_humanitaire_pred  \
# 0     [Rome, Bergame, russe, italien, De, Russie, Ch...                    0
# 1     [française, États, l’, Macédoine, du, Nord, Ba...                    0
# 2     [l’, Chine, l’, région, de, Wuhan, l’, l’, Eur...                    0
# 3     [grec, turc, grecs, turc, turc, l', Europe, ru...                    0
# 4     [FIGAROVOX.-, italien, l’, Quelles, l’, l’, l’...                    0
# ...                                                 ...                  ...
# 8913                                   [Suède, suédois]                    0
# 8914  [Bruxelles, Ankara, Bruxelles, Européens, syri...                    0
# 8915  [Européens, Brexit, Londres, Europe, Européens...                    0
# 8916  [France, France, La, Chine, La, France, la, Fr...                    0
# 8917  [Tunis, Afrique, du, Nord, Moyen-Orient, Pouss...                    0
#
#       is_securitaire_pred Année               category  \
# 0                       0  2020         Aucun des deux
# 1                       0  2020         Aucun des deux
# 2                       1  2020  Sécuritaire seulement
# 3                       0  2020         Aucun des deux
# 4                       1  2020  Sécuritaire seulement
# ...                   ...   ...                    ...
# 8913                    0  2021         Aucun des deux
# 8914                    0  2021         Aucun des deux
# 8915                    1  2020  Sécuritaire seulement
# 8916                    0  2020         Aucun des deux
# 8917                    1  2020  Sécuritaire seulement
#
#                                           replace_words  \
# 0     [Rome, Bergame, russe, italien, De, Russie, Ch...
# 1     [française, États, l’, Macédoine, du, Nord, Ba...
# 2     [l’, Chine, l’, région, de, Wuhan, l’, l’, Eur...
# 3     [grec, turc, grecs, turc, turc, l', Europe, ru...
# 4     [FIGAROVOX.-, italien, l’, Quelles, l’, l’, l’...
# ...                                                 ...
# 8913                                   [Suède, suédois]
# 8914  [Bruxelles, Ankara, Bruxelles, Européens, syri...
# 8915  [Européens, Brexit, Londres, Europe, Européens...
# 8916  [France, France, La, Chine, La, France, la, Fr...
# 8917  [Tunis, Afrique, du, Nord, Moyen-Orient, Pouss...
#
#                                  replaced_words_cleaned
# 0     [italien, bergame, russe, italien, de, russe, ...
# 1     [français, états, l’, macédoine, du, nord, bal...
# 2     [l’, chine, l’, région, de, wuhan, l’, l’, eur...
# 3     [grec, turc, grec, turc, turc, l', europe, rus...
# 4     [figarovox.-, italien, l’, quelles, l’, l’, l’...
# ...                                                 ...
# 8913                                 [suédois, suédois]
# 8914  [bruxelles, turc, bruxelles, européens, syrien...
# 8915  [européens, brexit, britannique, europe, europ...
# 8916  [français, français, la, chine, la, français, ...
# 8917  [tunisien, afrique, du, nord, moyen-orient, po...
#
# [8918 rows x 16 columns]

# %%
df_cleaned[["Journal","Titre","Date","Auteur","Texte","extrait_debut","extrait_fin","CJournal","texte_processed","replaced_words","Année","replaced_words_cleaned"]].to_csv('./data_cleaned/df_cleaned_v2.csv')

# %%
from tqdm import tqdm

stat_figaro = pd.DataFrame()
stat_monde = pd.DataFrame()
stat_liberation = pd.DataFrame()
stat_croix = pd.DataFrame()
stat_parisien = pd.DataFrame()
stat_echos = pd.DataFrame()

stat = pd.DataFrame()

for journal, dataframe in [
    ["Figaro", stat_figaro],
    ["Monde", stat_monde],
    ["Libération", stat_liberation],
    ["Croix", stat_croix],
    ["Parisien", stat_parisien],
    ["Echos", stat_echos],
] :
    print(f"Traitement de {journal}")
    df = df_cleaned.loc[df_cleaned.CJournal==journal]
    
    for year in df["Année"].unique():
        print(year)
        data = df.loc[df["Année"]==year]
    
        dict_humanitaire = {}
        dict_securitaire = {}

        for replaced_words in np.array(data.loc[data["is_humanitaire_pred"]==1, "replaced_words_cleaned"]) :
            for word in replaced_words :
                word = word.lower()

                if word not in dict_humanitaire.keys():
                    dict_humanitaire[word] = 1
                else :
                    dict_humanitaire[word] += 1

        for replaced_words in np.array(data.loc[data["is_securitaire_pred"]==1, "replaced_words_cleaned"]) :
            for word in replaced_words :
                word = word.lower()
                        
                if word not in dict_securitaire.keys():
                    dict_securitaire[word] = 1
                else :
                    dict_securitaire[word] += 1

        # Convertir les dictionnaires en dataframes
        df_huma = pd.DataFrame(list(dict_humanitaire.items()), columns=['mots', 'occurence_huma'])
        df_secu = pd.DataFrame(list(dict_securitaire.items()), columns=['mots', 'occurence_secu'])

        # Fusionner les deux dataframes sur la colonne 'Mot'
        result_df = pd.merge(df_huma, df_secu, on='mots', how='outer')

        ### Nombre d'articles
        print("Process nombre d'article")
        dict_humanitaire = {}
        dict_securitaire = {}

        for word in result_df.mots :            
            for replaced_words in data.loc[data["is_humanitaire_pred"]==1, "replaced_words_cleaned"] :
                word = word.lower()
                if word in replaced_words :  
                    if word not in dict_humanitaire.keys():
                        dict_humanitaire[word] = 1
                    else :
                        dict_humanitaire[word] += 1

            for replaced_words in data.loc[data["is_securitaire_pred"]==1, "replaced_words_cleaned"] :
                word = word.lower()
                if word in replaced_words : 
                    if word not in dict_securitaire.keys():
                        dict_securitaire[word] = 1
                    else :
                        dict_securitaire[word] += 1
        
        # Convertir les dictionnaires en dataframes
        df_huma = pd.DataFrame(list(dict_humanitaire.items()), columns=['mots', 'articles_huma'])
        df_secu = pd.DataFrame(list(dict_securitaire.items()), columns=['mots', 'articles_secu'])

        # Fusionner les deux dataframes sur la colonne 'Mot'
        result_df = pd.merge(result_df, df_huma, on='mots', how='left')
        result_df = pd.merge(result_df, df_secu, on='mots', how='left')

        # Remplacer les valeurs manquantes par 0
        result_df = result_df.fillna(0)
        result_df.insert(0,"journal",journal)
        result_df.insert(1,"annees",year)
        
        stat = pd.concat([
            stat,
            result_df
        ])
# Out:
# Traitement de Figaro
# 2020
# Process nombre d'article
# 2019
# Process nombre d'article
# 2018
# Process nombre d'article
# 2017
# Process nombre d'article
# 2016
# Process nombre d'article
# 2015
# Process nombre d'article
# 2014
# Process nombre d'article
# 2013
# Process nombre d'article
# 2011
# Process nombre d'article
# 2022
# Process nombre d'article
# 2021
# Process nombre d'article
# Traitement de Monde
# 2020
# Process nombre d'article
# 2019
# Process nombre d'article
# 2018
# Process nombre d'article
# 2017
# Process nombre d'article
# 2016
# Process nombre d'article
# 2015
# Process nombre d'article
# 2014
# Process nombre d'article
# 2012
# Process nombre d'article
# 2010
# Process nombre d'article
# 2009
# Process nombre d'article
# 2022
# Process nombre d'article
# 2021
# Process nombre d'article
# Traitement de Libération
# 2020
# Process nombre d'article
# 2019
# Process nombre d'article
# 2018
# Process nombre d'article
# 2017
# Process nombre d'article
# 2016
# Process nombre d'article
# 2015
# Process nombre d'article
# 2014
# Process nombre d'article
# 2013
# Process nombre d'article
# 2011
# Process nombre d'article
# 2010
# Process nombre d'article
# 2022
# Process nombre d'article
# 2021
# Process nombre d'article
# Traitement de Croix
# 2020
# Process nombre d'article
# 2019
# Process nombre d'article
# 2018
# Process nombre d'article
# 2017
# Process nombre d'article
# 2016
# Process nombre d'article
# 2015
# Process nombre d'article
# 2011
# Process nombre d'article
# 2009
# Process nombre d'article
# 2013
# Process nombre d'article
# 2022
# Process nombre d'article
# 2021
# Process nombre d'article
# Traitement de Parisien
# 2020
# Process nombre d'article
# 2019
# Process nombre d'article
# 2018
# Process nombre d'article
# 2017
# Process nombre d'article
# 2016
# Process nombre d'article
# 2015
# Process nombre d'article
# 2014
# Process nombre d'article
# 2022
# Process nombre d'article
# 2021
# Process nombre d'article
# Traitement de Echos
# 2020
# Process nombre d'article
# 2019
# Process nombre d'article
# 2018
# Process nombre d'article
# 2017
# Process nombre d'article
# 2016
# Process nombre d'article
# 2015
# Process nombre d'article
# 2022
# Process nombre d'article
# 2021
# Process nombre d'article

# %%
stat.to_csv('./data_cleaned/stat_nat_huma_secu.csv')

# %%
for journal in stat.journal.unique():
    print(journal, "Humanitaire")
    display(stat.loc[stat.journal == journal].sort_values(by=["occurence_huma"], ascending=False).head(5))
    
    print(journal, "Securitaire")
    display(stat.loc[stat.journal == journal].sort_values(by=["occurence_secu"], ascending=False).head(5))
# Out:
# Figaro Humanitaire
#    journal annees      mots  occurence_huma  occurence_secu  articles_huma  \
# 27  Figaro   2015  français           340.0           892.0           65.0
# 2   Figaro   2016      turc           302.0           808.0           47.0
# 15  Figaro   2015  allemand           284.0           840.0           62.0
# 13  Figaro   2015    europe           252.0           707.0           78.0
# 1   Figaro   2016  français           226.0          1069.0           53.0
#
#     articles_secu
# 27          177.0
# 2           134.0
# 15          181.0
# 13          205.0
# 1           212.0
# Figaro Securitaire
#    journal annees      mots  occurence_huma  occurence_secu  articles_huma  \
# 1   Figaro   2016  français           226.0          1069.0           53.0
# 93  Figaro   2016    europe           190.0           944.0           57.0
# 13  Figaro   2018  français           204.0           936.0           38.0
# 27  Figaro   2015  français           340.0           892.0           65.0
# 15  Figaro   2015  allemand           284.0           840.0           62.0
#
#     articles_secu
# 1           212.0
# 93          225.0
# 13          180.0
# 27          177.0
# 15          181.0
# Monde Humanitaire
#     journal annees      mots  occurence_huma  occurence_secu  articles_huma  \
# 1     Monde   2016  français           442.0          1347.0           96.0
# 157   Monde   2016      grec           367.0           922.0           69.0
# 156   Monde   2016      turc           348.0           944.0           85.0
# 32    Monde   2015  français           345.0          1117.0           59.0
# 33    Monde   2016    europe           329.0          1437.0          103.0
#
#      articles_secu
# 1            308.0
# 157          192.0
# 156          192.0
# 32           226.0
# 33           329.0
# Monde Securitaire
#     journal annees      mots  occurence_huma  occurence_secu  articles_huma  \
# 33    Monde   2016    europe           329.0          1437.0          103.0
# 1     Monde   2016  français           442.0          1347.0           96.0
# 64    Monde   2016  allemand           221.0          1171.0           78.0
# 32    Monde   2015  français           345.0          1117.0           59.0
# 156   Monde   2016      turc           348.0           944.0           85.0
#
#      articles_secu
# 33           329.0
# 1            308.0
# 64           273.0
# 32           226.0
# 156          192.0
# Libération Humanitaire
#        journal annees      mots  occurence_huma  occurence_secu  \
# 8   Libération   2016      grec           222.0           293.0
# 23  Libération   2018  français           210.0           450.0
# 12  Libération   2015  français           196.0           327.0
# 24  Libération   2018   italien           173.0           313.0
# 4   Libération   2015    syrien           135.0           189.0
#
#     articles_huma  articles_secu
# 8            20.0           38.0
# 23           34.0           84.0
# 12           33.0           64.0
# 24           25.0           57.0
# 4            29.0           53.0
# Libération Securitaire
#        journal annees      mots  occurence_huma  occurence_secu  \
# 23  Libération   2018  français           210.0           450.0
# 21  Libération   2016    europe           102.0           346.0
# 12  Libération   2015  français           196.0           327.0
# 24  Libération   2018   italien           173.0           313.0
# 8   Libération   2016      grec           222.0           293.0
#
#     articles_huma  articles_secu
# 23           34.0           84.0
# 21           30.0           75.0
# 12           33.0           64.0
# 24           25.0           57.0
# 8            20.0           38.0
# Croix Humanitaire
#     journal annees         mots  occurence_huma  occurence_secu  \
# 25    Croix   2018     français           229.0           295.0
# 4     Croix   2020         grec           154.0           170.0
# 0     Croix   2020         turc           150.0           206.0
# 161   Croix   2018  vénézuélien           112.0           129.0
# 3     Croix   2018      italien            92.0           194.0
#
#      articles_huma  articles_secu
# 25            28.0           50.0
# 4             22.0           26.0
# 0             20.0           28.0
# 161            7.0            9.0
# 3             23.0           40.0
# Croix Securitaire
#    journal annees      mots  occurence_huma  occurence_secu  articles_huma  \
# 25   Croix   2018  français           229.0           295.0           28.0
# 0    Croix   2020      turc           150.0           206.0           20.0
# 3    Croix   2018   italien            92.0           194.0           23.0
# 42   Croix   2018    europe            75.0           189.0           25.0
# 44   Croix   2018        l'            74.0           184.0           27.0
#
#     articles_secu
# 25           50.0
# 0            28.0
# 3            40.0
# 42           51.0
# 44           51.0
# Parisien Humanitaire
#      journal annees      mots  occurence_huma  occurence_secu  articles_huma  \
# 33  Parisien   2015  hongrois           339.0           347.0           28.0
# 42  Parisien   2015  allemand           263.0           316.0           32.0
# 26  Parisien   2015    europe           196.0           248.0           42.0
# 6   Parisien   2015  français           191.0           351.0           37.0
# 16  Parisien   2015    syrien           179.0           227.0           37.0
#
#     articles_secu
# 33           34.0
# 42           50.0
# 26           61.0
# 6            59.0
# 16           48.0
# Parisien Securitaire
#      journal annees      mots  occurence_huma  occurence_secu  articles_huma  \
# 6   Parisien   2015  français           191.0           351.0           37.0
# 33  Parisien   2015  hongrois           339.0           347.0           28.0
# 42  Parisien   2015  allemand           263.0           316.0           32.0
# 26  Parisien   2015    europe           196.0           248.0           42.0
# 16  Parisien   2015    syrien           179.0           227.0           37.0
#
#     articles_secu
# 6            59.0
# 33           34.0
# 42           50.0
# 26           61.0
# 16           48.0
# Echos Humanitaire
#    journal annees      mots  occurence_huma  occurence_secu  articles_huma  \
# 1    Echos   2015  allemand           321.0           568.0           46.0
# 6    Echos   2015  français           257.0           480.0           36.0
# 41   Echos   2016      turc           197.0           504.0           23.0
# 8    Echos   2015    europe           191.0           440.0           48.0
# 33   Echos   2015  hongrois           180.0           254.0           26.0
#
#     articles_secu
# 1           112.0
# 6            99.0
# 41           72.0
# 8           123.0
# 33           57.0
# Echos Securitaire
#    journal annees      mots  occurence_huma  occurence_secu  articles_huma  \
# 1    Echos   2015  allemand           321.0           568.0           46.0
# 41   Echos   2016      turc           197.0           504.0           23.0
# 6    Echos   2015  français           257.0           480.0           36.0
# 20   Echos   2016    europe           126.0           443.0           37.0
# 8    Echos   2015    europe           191.0           440.0           48.0
#
#     articles_secu
# 1           112.0
# 41           72.0
# 6            99.0
# 20          116.0
# 8           123.0

# %%
# Histogramme des occurrences de mots dans les articles humanitaires et sécuritaires
# plt.figure(figsize=(10, 6))
# sns.histplot(stat['occurence_huma'], label='Occurrences dans articles humanitaires', color='blue', kde=True)
# sns.histplot(stat['occurence_secu'], label='Occurrences dans articles sécuritaires', color='red', kde=True)
# plt.title('Histogramme des occurrences de mots dans articles humanitaires et sécuritaires')
# plt.xlabel('Occurrences')
# plt.ylabel('Nombre d\'occurrences')
# plt.legend()
# plt.show()

# Bar plot du nombre total d'articles humanitaires et sécuritaires
plt.figure(figsize=(10, 6))
totals = [stat['articles_huma'].sum(), stat['articles_secu'].sum()]
labels = ['Articles humanitaires', 'Articles sécuritaires']
plt.bar(labels, totals, color=['blue', 'red'])
plt.title('Nombre total d\'articles humanitaires et sécuritaires')
plt.ylabel('Nombre d\'articles')
plt.show()

# Visualisations segmentées par journal

# Création d'un plot pour le nombre total d'articles humanitaires et sécuritaires par journal
grouped_by_journal = stat.groupby('journal').agg({
    'articles_huma': 'sum',
    'articles_secu': 'sum'
})

grouped_by_journal.plot(kind='bar', figsize=(12, 6), color=['blue', 'red'])
plt.title('Nombre d\'articles humanitaires et sécuritaires par journal')
plt.ylabel('Nombre d\'articles')
plt.show()

# Visualisations segmentées par année

# Création d'un plot pour le nombre total d'articles humanitaires et sécuritaires par année
grouped_by_annee = stat.groupby('annees').agg({
    'articles_huma': 'sum',
    'articles_secu': 'sum'
})

grouped_by_annee.plot(kind='bar', figsize=(12, 6), color=['blue', 'red'])
plt.title('Nombre d\'articles humanitaires et sécuritaires par année')
plt.ylabel('Nombre d\'articles')
plt.show()

# Ces visualisations ne sont que quelques exemples. Tu peux explorer d'autres types de graphiques comme les lignes, les nuages de points, ou les graphiques combinés selon tes besoins.

# Création d'un plot pour le nombre total d'articles humanitaires et sécuritaires par année
grouped_by_annee = stat.groupby(['journal','mots']).agg({
    'articles_huma': 'sum',
    'articles_secu': 'sum'
})

grouped_by_annee.plot(kind='bar', figsize=(12, 6), color=['blue', 'red'])
plt.title('Nombre d\'articles humanitaires et sécuritaires par année')
plt.ylabel('Nombre d\'articles')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-132-b0d65c758e2e> in <module>
#       2 plt.figure(figsize=(10, 6))
#       3 sns.histplot(stat['occurence_huma'], label='Occurrences dans articles humanitaires', color='blue', kde=True)
# ----> 4 sns.histplot(stat['occurence_secu'], label='Occurrences dans articles sécuritaires', color='red', kde=True)
#       5 plt.title('Histogramme des occurrences de mots dans articles humanitaires et sécuritaires')
#       6 plt.xlabel('Occurrences')
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1430     if p.univariate:
#    1431
# -> 1432         p.plot_univariate_histogram(
#    1433             multiple=multiple,
#    1434             element=element,
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     573
#     574                 plot_func = ax.bar if self.data_variable == "x" else ax.barh
# --> 575                 artists = plot_func(
#     576                     hist["edges"],
#     577                     hist["heights"] - bottom,
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1472     def inner(ax, *args, data=None, **kwargs):
#    1473         if data is None:
# -> 1474             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1475
#    1476         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2484             else:  # horizontal
#    2485                 r.sticky_edges.x.append(l)
# -> 2486             self.add_patch(r)
#    2487             patches.append(r)
#    2488
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_patch(self, p)
#    2377         if p.get_clip_path() is None:
#    2378             p.set_clip_path(self.patch)
# -> 2379         self._update_patch_limits(p)
#    2380         self._children.append(p)
#    2381         p._remove_method = self._children.remove
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _update_patch_limits(self, patch)
#    2419                 updatey = False
#    2420         trf_to_data = patch_trf - self.transData
# -> 2421         xys = trf_to_data.transform(vertices)
#    2422         self.update_datalim(xys, updatex=updatex, updatey=updatey)
#    2423
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in transform(self, values)
#    1496
#    1497         # Transform the values
# -> 1498         res = self.transform_affine(self.transform_non_affine(values))
#    1499
#    1500         # Convert the result back to the shape of the input values.
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in transform_affine(self, points)
#    2421     def transform_affine(self, points):
#    2422         # docstring inherited
# -> 2423         return self.get_affine().transform(points)
#    2424
#    2425     def transform_non_affine(self, points):
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in get_affine(self)
#    2447             return self._b.get_affine()
#    2448         else:
# -> 2449             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2450                                    self._a.get_affine().get_matrix()))
#    2451
#
# ~\Anaconda3\lib\site-packages\numpy\core\overrides.py in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
word_to_eliminate = ["l'","la","de","-","l'","l'","l’","la","le"]
stat = stat.loc[~(stat.mots.isin(word_to_eliminate))]
for journal in stat.journal.unique():
    data = stat.loc[stat.journal==journal,["mots","occurence_huma","occurence_secu"]].groupby("mots").sum()
    
    data.sort_values("occurence_huma",ascending=False).head(10).plot(kind='bar', figsize=(12, 6))
    plt.title(f'{journal} : Top 10 des nationalités les plus fréquentes dand les articles humanitaires')
    plt.ylabel('Nombre d\'occurences')
    
    data.sort_values("occurence_secu",ascending=False).head(10).plot(kind='bar', figsize=(12, 6))
    plt.title(f'{journal} : Top 10 des nationalités les plus fréquentes dand les articles sécuritaire')
    plt.ylabel('Nombre d\'occurences')
    
    plt.show()

# %%
word_to_eliminate = ["l'","la","de","-","l'","l'","l’","la","le"]
stat = stat.loc[~(stat.mots.isin(word_to_eliminate))]
for journal in stat.journal.unique():
    data = stat.loc[stat.journal==journal,["mots","articles_huma","articles_secu"]].groupby("mots").sum()
    
    data.sort_values("articles_huma",ascending=False).head(10).plot(kind='bar', figsize=(12, 6))
    plt.title(f'{journal} : Top 10 des nationalités les plus fréquentes dand les articles humanitaires')
    plt.ylabel('Nombre d\'occurences')
    
    data.sort_values("articles_secu",ascending=False).head(10).plot(kind='bar', figsize=(12, 6))
    plt.title(f'{journal} : Top 10 des nationalités les plus fréquentes dand les articles sécuritaire')
    plt.ylabel('Nombre d\'occurences')
    
    plt.show()
